# %% [markdown]
# # Chains and cosmological constraints
#
# Loads the CosmoSIS `emcee` chain produced by the HMF+MOR forecast pipeline,
# inspects walker traces for burn-in/mixing, and makes a triangle (contour)
# plot of the cosmological parameter constraints (`omega_m`, `sigma8_input`).

# %%
import re
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
from getdist import MCSamples, plots

# must come after importing getdist.plots, which resets the mpl backend
# %matplotlib inline

CHAIN_FILE = Path("../output/scatter_fixed_02_area_A1.txt")

# %% [markdown]
# ## Load chain + header metadata

# %%
def read_cosmosis_chain(path):
    """Parse a CosmoSIS text-sampler output file.

    Returns the data array, the column names, and a dict of the
    `#key=value` header metadata (sampler, walkers, nsteps, etc).
    """
    columns = None
    meta = {}
    with open(path) as f:
        for line in f:
            if not line.startswith("#"):
                break
            if line.startswith("## "):
                continue
            header = line[1:].strip()
            if columns is None:
                columns = header.split()
                continue
            if "=" in header:
                key, _, val = header.partition("=")
                meta[key.strip()] = val.strip()

    data = np.loadtxt(path)
    return data, columns, meta


data, columns, meta = read_cosmosis_chain(CHAIN_FILE)
nwalkers = int(meta["walkers"])
nsteps = data.shape[0] // nwalkers

sampler_name = meta.get("sampler")
print(f"columns: {columns}")
print(f"sampler={sampler_name}  walkers={nwalkers}  steps={nsteps}  rows={data.shape[0]}")
# Out:
# columns: ['cosmological_parameters--omega_m', 'cosmological_parameters--sigma8_input', 'prior', 'post']
# sampler=emcee  walkers=20  steps=500  rows=10000

# %% [markdown]
# ## Reshape into (walker, step, param)
#
# CosmoSIS's `emcee` sampler writes rows step-major: all walkers for step 0,
# then all walkers for step 1, etc.

# %%
param_names = [c for c in columns if c not in ("prior", "post")]
param_idx = [columns.index(p) for p in param_names]

chain = data.reshape(nsteps, nwalkers, len(columns)).transpose(1, 0, 2)
log_post = chain[:, :, columns.index("post")]

print(f"parameters: {param_names}")
print(f"chain shape (walkers, steps, cols): {chain.shape}")
# Out:
# parameters: ['cosmological_parameters--omega_m', 'cosmological_parameters--sigma8_input']
# chain shape (walkers, steps, cols): (20, 500, 4)

# %% [markdown]
# ## Walker traces

# %%
fig, axes = plt.subplots(len(param_names) + 1, 1, figsize=(9, 2.2 * (len(param_names) + 1)), sharex=True)

for i, name in enumerate(param_names):
    ax = axes[i]
    for w in range(nwalkers):
        ax.plot(chain[w, :, param_idx[i]], color="C0", alpha=0.3, lw=0.7)
    ax.set_ylabel(name.split("--")[-1])

ax = axes[-1]
for w in range(nwalkers):
    ax.plot(log_post[w], color="C1", alpha=0.3, lw=0.7)
ax.set_ylabel("log-posterior")
ax.set_xlabel("step")

fig.suptitle("Walker traces — output/scatter_fixed_02_area_A1.txt", y=1.0)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Burn-in cut
#
# Adjust `burnin_frac` after looking at the traces above — the walkers should
# look like a stationary "fuzzy caterpillar" past the burn-in point.

# %%
burnin_frac = 0.5
burnin_steps = int(burnin_frac * nsteps)

flat_samples = chain[:, burnin_steps:, :].reshape(-1, len(columns))
flat_params = flat_samples[:, param_idx]
flat_post = flat_samples[:, columns.index("post")]

print(f"discarding first {burnin_steps}/{nsteps} steps as burn-in")
print(f"flattened samples: {flat_params.shape[0]}")
# Out:
# discarding first 250/500 steps as burn-in
# flattened samples: 5000

# %% [markdown]
# ## Triangle plot of cosmological constraints

# %%
labels = {
    "cosmological_parameters--omega_m": r"\Omega_m",
    "cosmological_parameters--sigma8_input": r"\sigma_8",
}
param_labels = [labels.get(p, p) for p in param_names]

samples = MCSamples(
    samples=flat_params,
    names=param_names,
    labels=param_labels,
    label="v1",
)

# fiducial values used to generate the mock data (see mass_function_like config)
fiducial = {
    "cosmological_parameters--omega_m": 0.318,
    "cosmological_parameters--sigma8_input": 0.80,
}
markers = {p: fiducial[p] for p in param_names if p in fiducial}

#param_names = [
#    "cosmological_parameters--omega_m",
#    "cosmological_parameters--sigma8_input",
#]

g = plots.get_subplot_plotter()
g.triangle_plot(samples, param_names, filled=True, markers=markers)
plt.show()
# Out:
# Removed no burn in

# %% [markdown]
# ## 1D marginalized constraints

# %%
for p, lbl in zip(param_names, param_labels):
    stats = samples.getMargeStats().parWithName(p)
    print(f"{lbl:>10s} = {stats.mean:.4f} +/- {stats.err:.4f}")
# Out:
#   \Omega_m = 0.3183 +/- 0.0033
#   \sigma_8 = 0.7999 +/- 0.0017

# %% [markdown]
# ## Comparing `config_key` assumptions
#
# `scripts/xxx.sh` refits the same mock data
# (generated with `frac_scatter_data = 0.20` fixed) while scanning the
# *assumed* model-side scatter, `frac_scatter_model`, away from that true
# value. `xxx.txt` itself is the matched case (`frac_scatter_model = 0.20`).
# Overlaying the resulting constraints shows how a mismatch between the
# assumed and true scatter biases and broadens `omega_m` / `sigma8_input`.

# %%
def load_scatter_run(path, burnin_frac=0.5, label=None):
    """Read a chain file and return a burnin-cut getdist MCSamples."""
    data_, columns_, meta_ = read_cosmosis_chain(path)
    nwalkers_ = int(meta_["walkers"])
    nsteps_ = data_.shape[0] // nwalkers_
    chain_ = data_.reshape(nsteps_, nwalkers_, len(columns_)).transpose(1, 0, 2)
    burnin_steps_ = int(burnin_frac * nsteps_)

    pnames_ = [c for c in columns_ if c not in ("prior", "post")]
    pidx_ = [columns_.index(p) for p in pnames_]
    flat_ = chain_[:, burnin_steps_:, :].reshape(-1, len(columns_))

    return MCSamples(
        samples=flat_[:, pidx_],
        names=pnames_,
        labels=[labels.get(p, p) for p in pnames_],
        label=label,
    )


# (path, config_value) — frac_scatter_data is fixed at 0.20 for all of them
scan_runs = [
    ("../output/scatter_fixed_02_area_A1.txt", 1000),
    ("../output/scatter_fixed_02_area_A2.txt", 2000),
    ("../output/scatter_fixed_02_sm20.txt", 4000),
    ("../output/scatter_fixed_02_area_A8.txt", 8000),
    #("../output/scatter_fixed_02_sm40.txt", 0.40),
]

# categorical palette (fixed hue order, CVD-safe) — 5 runs need to be told apart
# at a glance, which a single-hue light->dark ramp does not give at thin contour
# linewidths, so identity beats magnitude-encoding here
plot_colors = ["#2a78d6", "#eda100", "#008300", "#4a3aa7"] #"#1baf7a",

scan_samples = [
    load_scatter_run(path, label=rf"${config_value:.0f}\,{{\rm deg}}^2$")
    for path, config_value in scan_runs
]

for (path, config_value), s in zip(scan_runs, scan_samples):
    print(f"{path}: area_deg2={config_value:.0f}  samples={s.numrows}")
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# ../output/scatter_fixed_02_area_A1.txt: area_deg2=1000  samples=5000
# ../output/scatter_fixed_02_area_A2.txt: area_deg2=2000  samples=5000
# ../output/scatter_fixed_02_sm20.txt: area_deg2=4000  samples=5000
# ../output/scatter_fixed_02_area_A8.txt: area_deg2=8000  samples=5000

# %%
g = plots.get_subplot_plotter()
g.triangle_plot(
    scan_samples,
    param_names,
    filled=False,
    contour_colors=plot_colors,
    markers=markers,
    legend_labels=[s.label for s in scan_samples],
    legend_loc="upper right",
)

# Move the legend to sit outside the plot area
leg = g.legend
#leg.set_bbox_to_anchor((1.00, 0.95))     # x>1 pushes it to the right of the figure
leg.set_title("Survey area", prop={"size": 10, "weight": "bold"})
#leg.set_frame_on(False)                   # optional: cleaner without the box

g.fig.suptitle("Cosmological constraints vs. assumed model scatter", y=1.02)
#plt.tight_layout()
plt.show()

# %% [markdown]
# ### Constraint shift vs. scatter mismatch
#
# Mean ± 1σ for each parameter as a function of the assumed
# `frac_scatter_model`, with the matched run (`frac_scatter_model =
# frac_scatter_data = 0.10`) marked by the dashed vertical line and the
# fiducial truth by the dashed horizontal line. Point colors match the runs
# in the triangle plot above.

# %%
fig, axes = plt.subplots(1, len(param_names), figsize=(5 * len(param_names), 4))

config_values = [config_value for _, config_value in scan_runs]
for i, (p, lbl) in enumerate(zip(param_names, param_labels)):
    ax = axes[i]
    means = []
    errs = []
    for s in scan_samples:
        stats = s.getMargeStats().parWithName(p)
        means.append(stats.mean)
        errs.append(stats.err)

    ax.plot(config_values, means, "-", color="0.75", lw=1, zorder=1)
    for config_value, mean, err, color in zip(config_values, means, errs, plot_colors):
        ax.errorbar(config_value, mean, yerr=err, fmt="o", color=color, ecolor=color,
                     capsize=3, zorder=2)
    ax.axvline(0.10, color="0.6", ls="--", lw=1, label="matched (frac_scatter_data)")
    if p in fiducial:
        ax.axhline(fiducial[p], color="0.6", ls=":", lw=1, label="fiducial truth")
    ax.set_xlabel(r"Survey area [deg$^2$]")
    ax.set_ylabel(f"${lbl}$")
    ax.legend(fontsize=8)

fig.suptitle("Parameter constraints vs. survey area", y=1.02)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### MOR scatter as a free parameter (wrong)

# %%
from plot_utils import (
    load_run, scan_triangle, scan_constraint_plot,
)

#plot_params = [
#    "cosmological_parameters--omega_m",
#    "cosmological_parameters--sigma8_input",
#]

# (path, assumed scatter) — mock generated with frac_scatter_data = 0.20
scan_runs = [
    ("../output/scatter_free_02_sm00.txt", 0.00),
    ("../output/scatter_free_02_sm05.txt", 0.05),
    ("../output/scatter_free_02_sm10.txt", 0.10),
    ("../output/scatter_free_02_sm20.txt", 0.20),
    ("../output/scatter_free_02_sm40.txt", 0.40),
]

scan_samples = [
    load_run(path, label=rf"$\sigma_{{\rm assumed}} = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]

plot_params = scan_samples[0].getParamNames().list()

# Triangle
g = scan_triangle(scan_samples, plot_params, legend_title="Scatter prior", filled=False)
g.fig.suptitle("Cosmological constraints vs. assumed model scatter prior", y=1.02)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"$\sigma_{\ln O}^{\rm assumed}$",
    ref_x=0.20,   # matched = true scatter
)
fig.suptitle("Parameter constraints vs. assumed model scatter(prior)", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### MOR scatter fixed

# %%
# (path, assumed scatter) — mock generated with frac_scatter_data = 0.20
scan_runs = [
    ("../output/scatter_fixed_02_sm00.txt", 0.00),
    ("../output/scatter_fixed_02_sm05.txt", 0.05),
    ("../output/scatter_fixed_02_sm10.txt", 0.10),
    ("../output/scatter_fixed_02_sm20.txt", 0.20),
    ("../output/scatter_fixed_02_sm40.txt", 0.40),
]

scan_samples = [
    load_run(path, label=rf"$\sigma_{{\rm assumed}} = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]

plot_params = scan_samples[0].getParamNames().list()

# Triangle
g = scan_triangle(scan_samples, plot_params, legend_title="Assumed Scatter", filled=False)
g.fig.suptitle("Cosmological constraints vs. assumed model scatter", y=1.02)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"$\sigma_{\ln O}^{\rm assumed}$",
    ref_x=0.20,   # matched = true scatter
)
fig.suptitle("Parameter constraints vs. assumed model scatter", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Different mass threshold (minmum mass)

# %%
def fmt_mass(m):
    """Format a mass in Msun/h as LaTeX scientific notation."""
    exp = int(np.floor(np.log10(m)))
    mant = m / 10**exp
    if np.isclose(mant, 1.0):
        return rf"10^{{{exp}}}"
    return rf"{mant:g}\times 10^{{{exp}}}"

# (path, mass threshold Mmin in Msun/h) — mock generated with frac_scatter_data = 0.20
scan_runs = [
    ("../output/scatter_fixed_02_sm20.txt",  2e14),
    ("../output/scatter_fixed_02_M5e13.txt", 5e13),
]

scan_samples = [
    load_run(path, label=rf"$M_{{\min}} = {fmt_mass(cv)}\,M_\odot/h$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Mass threshold $M_{\min}$",
    filled=False,
)
g.fig.suptitle("Cosmological constraints vs. mass threshold", y=1.02)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"Mass threshold $M_{\min}$ [$M_\odot/h$]",
    ref_x=None,   # no natural reference value for a mass-threshold scan
)
fig.suptitle("Parameter constraints vs. mass threshold", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Different mass range

# %%
# (path, lower mass edge mmin in Msun/h; window is [mmin, 10*mmin])
# — mock generated with frac_scatter_data = 0.20
scan_runs = [
    ("../output/scatter_fixed_02_mass_M5e13-5e14.txt", 5e13),
    ("../output/scatter_fixed_02_mass_M1e14-1e15.txt", 1e14),
    ("../output/scatter_fixed_02_mass_M5e14-5e15.txt", 5e14),
]
scan_samples = [
    load_run(
        path,
        label=rf"$M \in [{fmt_mass(mmin)},\,{fmt_mass(10*mmin)}]\,M_\odot/h$",
    )
    for path, mmin in scan_runs
]
config_values = [mmin for _, mmin in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Mass window",
    filled=False,
)
g.fig.suptitle("Cosmological constraints vs. mass window", y=1.02)
plt.show()

# Constraints vs config axis (x = lower mass edge)
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"Lower mass edge $M_{\min}$ [$M_\odot/h$]",
    ref_x=None,
)
fig.suptitle("Parameter constraints vs. lower mass edge", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Different MOR scatter (data)

# %%
# (path, data scatter frac_scatter) — correct-fixed sweep over true MOR scatter
# Fixed: M_min = 2e14 Msun/h, area = 4000 deg^2
scan_runs = [
    ("../output/scatter_fixed_sd_sm05.txt", 0.05),
    ("../output/scatter_fixed_sd_sm10.txt", 0.10),
    ("../output/scatter_fixed_sd_sm20.txt", 0.20),
    ("../output/scatter_fixed_sd_sm40.txt", 0.40),
    ("../output/scatter_fixed_sd_sm80.txt", 0.80),
]
scan_samples = [
    load_run(path, label=rf"$\sigma_{{\rm true}} = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"True scatter $\sigma_{\rm true}$",
    filled=False,
)
g.fig.suptitle(
    "Cosmological constraints vs. true MOR scatter (correct-fixed)",
    y=1.02,
)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"True scatter $\sigma_{\rm true}$ ($f_{\rm obs}$)",
    ref_x=None,   # no single reference value; the whole axis is the variable
)
fig.suptitle("Parameter constraints vs. true MOR scatter", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### MOR scatter as a free parameter (informing priors)

# %%
# --------------------------------------------------------------
# Prior-scan analysis: fixed true scatter = 0.20,
# varying width of Gaussian prior on model scatter.
# Fixed: M_min = 2e14 Msun/h, area = 4000 deg^2
#
# The "fixed" chain uses scatter_model = 0.20 (delta function at truth),
# so it's the limiting case of prior_width -> 0.
# --------------------------------------------------------------

# (path, prior width) — center is always 0.20 (= truth) for this scan
scan_runs = [
    ("../output/scatter_fixed_sd_sm20.txt", 0.0),   # fixed at truth
    ("../output/prior_scan_sd20_c20_w01.txt", 0.01),
    ("../output/prior_scan_sd20_c20_w05.txt", 0.05),
    ("../output/prior_scan_sd20_c20_w20.txt", 0.20),
]

# Human-readable labels for the legend
def prior_label(w):
    if w == 0.0:
        return r"fixed at truth ($\sigma_{\rm prior}\to 0$)"
    return rf"$\sigma_{{\rm prior}} = {w:.2f}$"

scan_samples = [
    load_run(path, label=prior_label(w))
    for path, w in scan_runs
]
prior_widths = [w for _, w in scan_runs]

plot_params = scan_samples[0].getParamNames().list()

print("Parameters:", plot_params)

for path, w in scan_runs:
    chain = load_run(path)
    means = chain.getMeans()
    stds = np.sqrt(chain.getVars())
    print(f"width={w}: N={len(chain.samples)}")
    for i, name in enumerate(plot_params):
        print(f"  {name}: {means[i]:.4f} ± {stds[i]:.4f}")
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Parameters: ['cosmological_parameters--omega_m', 'cosmological_parameters--sigma8_input']
# Removed no burn in
# width=0.0: N=5000
#   cosmological_parameters--omega_m: 0.3181 ± 0.0016
#   cosmological_parameters--sigma8_input: 0.8000 ± 0.0009
# Removed no burn in
# width=0.01: N=5000
#   cosmological_parameters--omega_m: 0.3180 ± 0.0018
#   cosmological_parameters--sigma8_input: 0.8000 ± 0.0009
# Removed no burn in
# width=0.05: N=5000
#   cosmological_parameters--omega_m: 0.3181 ± 0.0018
#   cosmological_parameters--sigma8_input: 0.8000 ± 0.0010
# Removed no burn in
# width=0.2: N=5000
#   cosmological_parameters--omega_m: 0.3179 ± 0.0017
#   cosmological_parameters--sigma8_input: 0.8000 ± 0.0009

# %%
# --------------------------------------------------------------
# Triangle plot — joint posterior across prior widths
# --------------------------------------------------------------
g = scan_triangle(
    scan_samples, plot_params,
    legend_title="Prior width on model scatter",
    filled=False,
)
g.fig.suptitle(
    r"Cosmology vs. prior width on $\sigma_{\rm scatter}$ "
    r"(true scatter fixed at 0.20)",
    y=1.02,
)
plt.show()

# --------------------------------------------------------------
# Constraint-vs-axis plot — parameter width vs prior width
# --------------------------------------------------------------
fig, _ = scan_constraint_plot(
    scan_samples, prior_widths, plot_params,
    xlabel=r"Prior width $\sigma_{\rm prior}$",
    ref_x=None,
)
fig.suptitle(
    r"Cosmological constraints vs. external calibration precision"
    r" (centered at truth, $\sigma_{\rm true}=0.20$)",
    y=1.02,
)
plt.show()

# %%
# --------------------------------------------------------------
# Prior-center scan at fixed tight width (0.01)
# All three prior-scan chains use width 0.01; only the prior center varies.
# Truth: sigma_true = 0.20.
# --------------------------------------------------------------
scan_runs = [
    ("../output/scatter_fixed_sd_sm20.txt", 0.20),   # fixed at truth
    ("../output/prior_scan_sd20_c10_w01.txt", 0.10), # tight biased low
    ("../output/prior_scan_sd20_c20_w01.txt", 0.20), # tight at truth
    ("../output/prior_scan_sd20_c40_w01.txt", 0.40), # tight biased high
]

def center_label(c, is_fixed=False):
    if is_fixed:
        return rf"fixed at truth ($\sigma = {c:.2f}$)"
    return rf"$\mu_{{\rm prior}} = {c:.2f}$"

scan_samples = [
    load_run(path, label=center_label(c, is_fixed=(i == 0)))
    for i, (path, c) in enumerate(scan_runs)
]
prior_centers = [c for _, c in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# --------------------------------------------------------------
# Triangle plot — joint posterior across prior centers
# --------------------------------------------------------------
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Prior center on $\sigma_{\rm scatter}$",
    filled=False,
)
g.fig.suptitle(
    r"Cosmology vs. biased $\mu_{\rm prior}$ ($\sigma_{\rm prior}=0.01$, $\sigma_{\rm true}=0.20$)",
    y=1.02,
    fontsize=12,
)
plt.show()

# --------------------------------------------------------------
# Constraint-vs-axis plot — parameter values vs prior center
# --------------------------------------------------------------
fig, _ = scan_constraint_plot(
    scan_samples, prior_centers, plot_params,
    xlabel=r"Prior center $\mu_{\rm prior}$ on $\sigma_{\rm scatter}$",
    ref_x=0.20,   # truth — mark the correctly-centered prior
)
fig.suptitle(
    r"Cosmology vs. $\mu_{\rm prior}$ (tight prior, $\sigma_{\rm true}=0.20$)",
    y=1.02,
    fontsize=12,
)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
# --------------------------------------------------------------
# Truth: sigma_true = 0.20.
# --------------------------------------------------------------
scan_runs = [
    ("../output/slope_sd20_ad10_am05.txt", 0.5), # tight biased low
    ("../output/scatter_fixed_sd_sm20.txt", 1.0),   # fixed at truth
    ("../output/slope_sd20_ad10_am15.txt", 1.5), # tight at truth
    #("../output/prior_scan_sd20_c40_w01.txt", 0.40), # tight biased high
]

scan_samples = [
    load_run(path, label=rf"$slope (\alpha) = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Model slope $\alpha_{\rm true}$",
    filled=False,
)
g.fig.suptitle(
    "Cosmological constraints vs. Model MOR slope (data slopes are 1.0)",
    y=1.02,
)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"Model slope $\alpha_{\rm true}$ ($f_{\rm obs}$)",
    ref_x=None,   # no single reference value; the whole axis is the variable
)
fig.suptitle("Parameter constraints vs. model MOR slope", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
# --------------------------------------------------------------
# Comparison: constant scatter vs. correctly-specified O-dependent scatter.
# Both runs have gamma_scatter_model matching gamma_scatter_data exactly
# (no mis-specification in either) -- this isolates whether O-dependent
# scatter changes the contour at all, independent of any fitting bias.
# --------------------------------------------------------------
scan_runs = [
    ("../output/scatter_gt30_free_frac.txt", 0.00),      # no gamma at all (constant)
    ("../output/scatter_gt30_free_gamma_frac.txt", 0.30),  # correctly specified (= truth)
]
scan_samples = [
    load_run(path, label=rf"$\gamma = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Scatter model",
    filled=False,
)
g.fig.suptitle(
    r"Cosmological constraints: constant vs. observable-dependent"
    "\n" r"intrinsic scatter (both correctly modeled, $\sigma_{\ln O}=0.20$)",
    y=1.02,
)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"Scatter slope $\gamma$ (data = model, both cases)",
    ref_x=0.00,   # constant-scatter case as the baseline to compare against
)
fig.suptitle("Parameter constraints: constant vs. O-dependent scatter", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in

# %%
# --------------------------------------------------------------
# Comparison: constant scatter vs. correctly-specified O-dependent scatter.
# Both runs have gamma_scatter_model matching gamma_scatter_data exactly
# (no mis-specification in either) -- this isolates whether O-dependent
# scatter changes the contour at all, independent of any fitting bias.
# --------------------------------------------------------------
scan_runs = [
    ("../output/scatter_gt30_gm_scan_gm00.txt", 0.00),      # no gamma at all (constant)
    ("../output/scatter_gt30_gm_scan_gm30.txt", 0.30),  # correctly specified (= truth)
]
scan_samples = [
    load_run(path, label=rf"$\gamma = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Scatter model",
    filled=False,
)
g.fig.suptitle(
    r"Cosmological constraints: constant vs. observable-dependent"
    "\n" r"intrinsic scatter (both correctly modeled, $\sigma_{\ln O}=0.20$)",
    y=1.02,
)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"Scatter slope $\gamma$ (data = model, both cases)",
    ref_x=0.00,   # constant-scatter case as the baseline to compare against
)
fig.suptitle("Parameter constraints: constant vs. O-dependent scatter", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in

# %%
# --------------------------------------------------------------
# Truth: frac_scatter_data = 0.20, gamma_scatter_data = 0.30
# (intrinsic scatter is O-dependent). Model's assumed gamma_scatter_model
# scanned from 0.00 (mis-specified, treats scatter as constant) to
# 0.30 (correctly specified, matches the truth).
# --------------------------------------------------------------
scan_runs = [
    ("../output/scatter_gt30_gm_scan_gm00.txt", 0.00),  # fully mis-specified (constant)
    ("../output/scatter_gt30_gm_scan_gm15.txt", 0.15),
    ("../output/scatter_gt30_gm_scan_gm30.txt", 0.30),  # correctly specified (= truth)
    ("../output/scatter_gt30_gm_scan_gm45.txt", 0.45),
]
scan_samples = [
    load_run(path, label=rf"$\gamma_{{\rm model}} = {cv:.2f}$")
    for path, cv in scan_runs
]
config_values = [cv for _, cv in scan_runs]
plot_params = scan_samples[0].getParamNames().list()

# Triangle plot
g = scan_triangle(
    scan_samples, plot_params,
    legend_title=r"Assumed scatter slope $\gamma_{\rm model}$",
    filled=False,
)
g.fig.suptitle(
    r"Cosmological constraints vs. assumed scatter $O$-dependence $\gamma_{\rm model}$"
    "\n" r"(truth: $\gamma_{\rm data}=0.30$, $\sigma_{\ln O}=0.20$)",
    y=1.02,
)
plt.show()

# Constraints vs config axis
fig, _ = scan_constraint_plot(
    scan_samples, config_values, plot_params,
    xlabel=r"Assumed scatter slope $\gamma_{\rm model}$",
    ref_x=0.30,   # the truth -- gm=0.30 is the correctly-specified point
)
fig.suptitle("Parameter constraints vs. assumed scatter O-dependence", y=1.02)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
