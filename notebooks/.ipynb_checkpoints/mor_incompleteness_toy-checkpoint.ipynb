# %% [markdown]
# # MOR under incompleteness: a two-bin toy study
#
# This notebook isolates a single effect: **how does a threshold-based selection cut bias a naïve fit of a mass–observable relation (MOR), and does a selection-aware likelihood remove that bias?**
#
# Dependency: `numpy` + `scipy` + `matplotlib`. The setup mirrors the physical picture: two disjoint mass bins with intrinsic log-normal scatter, a single observable threshold that preferentially kills the low-mass, low-observable clusters.
#
# ## Physical setup
#
# We assume a log-linear MOR
# $$\ln \mathrm{Obs} = A + \alpha \, \ln(M / M_\mathrm{piv}) + \varepsilon, \qquad \varepsilon \sim \mathcal{N}(0, \sigma_{\ln})$$
#
# with fiducial $A = 0$, $\alpha = 1.5$, $\sigma_{\ln} = 0.2$, $M_\mathrm{piv} = 3\times 10^{14}\,M_\odot/h$. This form is the standard log-normal MOR used throughout the cluster-cosmology literature ([Lima & Hu 2005](https://arxiv.org/abs/astro-ph/0503363); [Allen, Evrard & Mantz 2011](https://arxiv.org/abs/1103.4829)).
#
# Clusters are drawn in two disjoint bins, uniform in $\log_{10}M$:
# - Low: $M \in [5\times 10^{13}, 10^{14}]\,M_\odot/h$
# - High: $M \in [5\times 10^{14}, 10^{15}]\,M_\odot/h$
#
# Detection is a single threshold: a cluster survives iff $y = \ln \mathrm{Obs} > y_\mathrm{min}$. Because low-mass clusters have lower mean $y$, a single threshold **automatically** produces higher incompleteness in the low bin — no manual tuning of two separate loss fractions. Real X-ray or SZ surveys behave this way (see e.g. [Vikhlinin et al. 2009](https://arxiv.org/abs/0805.2207); [Mantz et al. 2010](https://arxiv.org/abs/0909.3098)).
#
# ## What we test
#
# Two fitting procedures on the *detected* sample:
#
# 1. **OLS** — ordinary least squares on $(x_i, y_i)$ with $x = \ln(M/M_\mathrm{piv})$, $y = \ln \mathrm{Obs}$. Estimates $(A, \alpha)$ from the normal equations and $\sigma$ from the residual RMS. **Assumes the sample is a fair draw** — it has no notion of missing points.
#
# 2. **Selection-aware MLE** — maximum-likelihood fit of the *truncated* Gaussian likelihood, which explicitly conditions on detection:
# $$p(y \mid x, \text{detected}) = \frac{\mathcal{N}(y \mid A + \alpha x, \sigma)}{P(y > y_\mathrm{min} \mid x)}$$
# where the denominator is the Gaussian survival function evaluated at the threshold. In the limit $y_\mathrm{min} \to -\infty$, this reduces to OLS.
#
# We scan $y_\mathrm{min}$ over a grid, run many mock realisations at each threshold, and plot the fitted $(\sigma, \alpha, A)$ vs the resulting total incompleteness $f_\mathrm{total}$.
#
# ## References
# - **Kelly 2007** ([arXiv:0705.2774](https://arxiv.org/abs/0705.2774)) — definitive treatment of regression with selection + measurement error in astronomy. §5 covers truncation explicitly. The paper behind `linmix`.
# - **Hogg, Bovy & Lang 2010** ([arXiv:1008.4686](https://arxiv.org/abs/1008.4686)) — §7 is the friendliest short intro to selection effects in fitting.
# - **Lima & Hu 2005** ([arXiv:astro-ph/0503363](https://arxiv.org/abs/astro-ph/0503363)) — self-calibration of the observable–mass distribution in cluster counts.
# - **Stanek et al. 2006** ([arXiv:astro-ph/0602324](https://arxiv.org/abs/astro-ph/0602324)) — worked example of scatter measurement under flux-limited selection.
# - **Grandis, Mohr, Dietrich et al. 2019** ([arXiv:1902.11265](https://arxiv.org/abs/1902.11265)) — selection-induced biases in the eROSITA context (closest paper to your project).
# - **Mantz 2019** ([arXiv:1902.06791](https://arxiv.org/abs/1902.06791)) — generalised selection-aware method for cluster scaling relations.
# - **Sereno & Ettori 2015 (CoMaLit-I)** ([arXiv:1502.05413](https://arxiv.org/abs/1502.05413)) — Bayesian treatment of scaling relations under truncation.
# - **Isobe, Feigelson, Akritas & Babu 1990** (ApJ 364, 104; [ADS](https://ui.adsabs.harvard.edu/abs/1990ApJ...364..104I)) — the classic "which regression?" paper on OLS variants in astronomy.

# %% [markdown]
# ## 1 — Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import minimize

# ---- Fiducial MOR parameters ----
A_TRUE     = 0.0            # intercept (choice of Obs units)
ALPHA_TRUE = 1.5            # slope
SIGMA_TRUE = 0.2            # intrinsic scatter in ln(Obs)
M_PIV      = 3e14           # pivot mass, M_sun/h

# ---- Mass bins (disjoint) ----
M_EDGES_LOW  = (5e13, 1e14)
M_EDGES_HIGH = (5e14, 1e15)

# ---- Sample size per bin ----
N_LOW  = 100
N_HIGH = 50

# Master RNG (a fresh RNG is used for each realisation inside the scan so
# results are reproducible per (threshold, realisation) index)
rng_master = np.random.default_rng(42)

# ---- Mass-dependent scatter parameters ----
# sigma_lnO(M) = SIGMA_TRUE * (M / M_piv) ** GAMMA_SCATTER
# GAMMA_SCATTER = 0    -> constant scatter (original behaviour, backward compatible)
# GAMMA_SCATTER < 0    -> LARGER scatter at low mass (physically motivated)
# GAMMA_SCATTER > 0    -> larger scatter at high mass
GAMMA_SCATTER = -0.30    # try 0.0, -0.3, -0.6 to see the effect grow

# %% [markdown]
# ### Note on mass-dependent scatter
#
# The default scatter model in this notebook is now mass-dependent:
# $$\sigma_{\ln O}(M) = \sigma_0 \cdot (M / M_\mathrm{piv})^{\gamma_\mathrm{scatter}}$$
#
# This is the standard parameterization for X-ray L–M and Y–M relations, following [Evrard et al. 2014](https://arxiv.org/abs/1403.1456) and [Mantz et al. 2016](https://arxiv.org/abs/1606.03407). Setting $\gamma_\mathrm{scatter} = 0$ recovers the constant-scatter case, and $\gamma_\mathrm{scatter} < 0$ produces **larger scatter at low mass** — physically motivated because low-mass clusters are proportionally more affected by feedback, cool-core disruption, and merger activity.
#
# **What we're testing.** How does selection bias interact with mass-dependent scatter? Under threshold-based selection, the low-mass bin already loses more clusters than the high-mass bin. If the low-mass bin *also* has larger intrinsic scatter, then:
# 1. More low-mass clusters live near the threshold (fat tail crossing $y_\mathrm{min}$).
# 2. The truncation reshapes a *wider* Gaussian in the low bin than in the high bin.
# 3. A fit that assumes constant scatter mis-specifies the underlying model *twice*: once through the truncation, once through the wrong scatter shape.
#
# **What the two fits assume.** Both OLS and the selection-aware fit as currently coded assume **constant** scatter. So they are both mis-specified relative to the truth when $\gamma \neq 0$. This is deliberate: it lets us quantify the bias from getting the scatter shape wrong, which is the toy analogue of the pipeline's `wrong-fixed` and `marginalise` misspecification modes.

# %% [markdown]
# ## 2 — Mock cluster catalogue
#
# Draw $N_\mathrm{low}$ + $N_\mathrm{high}$ clusters uniformly in $\log_{10} M$ within each bin, then compute $\ln \mathrm{Obs}$ from the MOR with intrinsic log-normal scatter. Returns arrays in the fit variables $x = \ln(M/M_\mathrm{piv})$ and $y = \ln \mathrm{Obs}$, plus a bin label (0 = low, 1 = high) for bookkeeping.
#
# *Design note.* Uniform in $\log_{10} M$ within each bin is a deliberate simplification: real halos follow the mass function, so the low edge of each bin is more populated than the high edge. Swapping in HMF-weighted sampling would make the low-mass bin's centroid slightly lower and would amplify the biases below, but doesn't change the qualitative story. Left as an easy extension.

# %%
def sigma_of_M(M, sigma0=SIGMA_TRUE, gamma=GAMMA_SCATTER, M_piv=M_PIV):
    """Mass-dependent log-normal scatter.
    sigma_lnO(M) = sigma0 * (M / M_piv) ** gamma
    Following the standard form (Evrard+2014 arXiv:1403.1456; Mantz+2016 arXiv:1606.03407).
    """
    return sigma0 * (M / M_piv) ** gamma


def generate_mock(N_low, N_high, M_edges_low, M_edges_high, rng,
                  gamma=GAMMA_SCATTER):
    logM_low  = rng.uniform(np.log10(M_edges_low[0]),  np.log10(M_edges_low[1]),  N_low)
    logM_high = rng.uniform(np.log10(M_edges_high[0]), np.log10(M_edges_high[1]), N_high)
    logM = np.concatenate([logM_low, logM_high])
    M = 10 ** logM
    x = np.log(M / M_PIV)
    y_mean = A_TRUE + ALPHA_TRUE * x
    # Per-cluster scatter width — this is the only change vs constant-sigma version
    sigma_per_cluster = sigma_of_M(M, sigma0=SIGMA_TRUE, gamma=gamma, M_piv=M_PIV)
    y = y_mean + rng.normal(0.0, 1.0, size=len(x)) * sigma_per_cluster
    bin_label = np.concatenate([np.zeros(N_low, dtype=int),
                                np.ones(N_high, dtype=int)])
    return M, x, y, bin_label

# %% [markdown]
# ## 3 — Two fits
#
# ### 3.1 OLS
#
# Closed-form linear regression: minimise $\sum_i (y_i - A - \alpha x_i)^2$, then estimate $\sigma$ from the residual RMS with $N-2$ degrees of freedom (unbiased under Gaussian errors, *no truncation*).
#
# ### 3.2 Selection-aware MLE
#
# Negative log-likelihood of the truncated Gaussian, minimised with Nelder–Mead. We parametrise as $(A, \alpha, \ln\sigma)$ so the sampler stays in unbounded space and $\sigma > 0$ is automatic.
#
# $$-\ln \mathcal{L}(A, \alpha, \sigma) = -\sum_i \left[ \ln \phi\!\left(\frac{y_i - A - \alpha x_i}{\sigma}\right) - \ln \sigma - \ln P(y > y_\mathrm{min} \mid x_i) \right]$$
#
# with $\phi$ the standard normal PDF and $P(y > y_\mathrm{min} \mid x_i) = 1 - \Phi\!\left((y_\mathrm{min} - A - \alpha x_i)/\sigma\right)$. This is exactly the structure of the migration matrix in your `scatter_massde.py`, just applied to individual points rather than binned counts.

# %%
def fit_ols(x, y):
    """Ordinary least squares; sigma from residual RMS with N-2 dof."""
    if len(x) < 3:
        return np.nan, np.nan, np.nan
    alpha_hat, A_hat = np.polyfit(x, y, 1)   # returns [slope, intercept]
    resid = y - (A_hat + alpha_hat * x)
    sigma_hat = np.std(resid, ddof=2)
    return A_hat, alpha_hat, sigma_hat


def neg_loglike_truncated(params, x, y, y_min):
    """Negative log-likelihood of the truncated-Gaussian MOR."""
    A, alpha, log_sigma = params
    sigma = np.exp(log_sigma)
    mu = A + alpha * x
    log_pdf  = norm.logpdf(y, loc=mu, scale=sigma)
    log_surv = norm.logsf(y_min, loc=mu, scale=sigma)  # ln P(y > y_min | x)
    return -np.sum(log_pdf - log_surv)


def fit_selection_aware(x, y, y_min, init=(0.0, 1.5, 0.2)):
    """MLE of the truncated Gaussian likelihood. `init` = (A, alpha, sigma)."""
    if len(x) < 3:
        return np.nan, np.nan, np.nan
    x0 = [init[0], init[1], np.log(init[2])]
    result = minimize(
        neg_loglike_truncated, x0=x0, args=(x, y, y_min),
        method='Nelder-Mead',
        options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 10000},
    )
    if not result.success:
        return np.nan, np.nan, np.nan
    A, alpha, log_sigma = result.x
    return A, alpha, np.exp(log_sigma)


# ---------------------------------------------------------------------------
# H2 model: mass-dependent scatter, sigma_i = sigma_0 * (M_i/M_piv)^gamma
# Since x = ln(M/M_piv), this is equivalently sigma_i = sigma_0 * exp(gamma * x_i).
# H2 fits estimate 4 parameters: (A, alpha, sigma_0, gamma).
# ---------------------------------------------------------------------------

def neg_loglike_h2_untrunc(params, x, y):
    """Un-truncated Gaussian log-likelihood with mass-dependent sigma.
    Parameterisation: log_sigma0 (unbounded internal), gamma (unbounded).
    """
    A, alpha, log_sigma0, gamma = params
    sigma0 = np.exp(log_sigma0)
    sigma_i = sigma0 * np.exp(gamma * x)   # per-cluster width
    mu = A + alpha * x
    return -np.sum(norm.logpdf(y, loc=mu, scale=sigma_i))


def fit_h2_untrunc(x, y, init=(0.0, 1.5, 0.2, 0.0)):
    """H2 fit WITHOUT selection modeling. Heteroscedastic Gaussian MLE.
    Analogue of OLS for the mass-dependent-scatter model.
    init: (A_init, alpha_init, sigma0_init, gamma_init).
    """
    if len(x) < 4:
        return np.nan, np.nan, np.nan, np.nan
    x0 = [init[0], init[1], np.log(init[2]), init[3]]
    r = minimize(neg_loglike_h2_untrunc, x0=x0, args=(x, y),
                 method='Nelder-Mead',
                 options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 20000})
    if not r.success:
        return np.nan, np.nan, np.nan, np.nan
    A, alpha, log_sigma0, gamma = r.x
    return A, alpha, np.exp(log_sigma0), gamma


def neg_loglike_h2_truncated(params, x, y, y_min):
    """Truncated-Gaussian log-likelihood with mass-dependent sigma.
    Same structure as H1 selection-aware, but sigma varies per point.
    """
    A, alpha, log_sigma0, gamma = params
    sigma0 = np.exp(log_sigma0)
    sigma_i = sigma0 * np.exp(gamma * x)
    mu = A + alpha * x
    log_pdf  = norm.logpdf(y, loc=mu, scale=sigma_i)
    log_surv = norm.logsf(y_min, loc=mu, scale=sigma_i)   # per-point survival prob
    return -np.sum(log_pdf - log_surv)


def fit_h2_sel(x, y, y_min, init=(0.0, 1.5, 0.2, 0.0)):
    """H2 fit WITH selection modeling. Correctly specified when both mass-dep
    scatter is present AND selection is threshold-based.
    """
    if len(x) < 4:
        return np.nan, np.nan, np.nan, np.nan
    x0 = [init[0], init[1], np.log(init[2]), init[3]]
    r = minimize(neg_loglike_h2_truncated, x0=x0, args=(x, y, y_min),
                 method='Nelder-Mead',
                 options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 20000})
    if not r.success:
        return np.nan, np.nan, np.nan, np.nan
    A, alpha, log_sigma0, gamma = r.x
    return A, alpha, np.exp(log_sigma0), gamma

def neg_loglike_h2_truncated_perpoint(params, x, y, y_min_arr):
    """H2 truncated-Gaussian log-likelihood with per-point y_min AND per-point sigma.
    Combines the per-point threshold structure (needed for fraction-based selection)
    with mass-dependent scatter.
    """
    A, alpha, log_sigma0, gamma = params
    sigma0 = np.exp(log_sigma0)
    sigma_i = sigma0 * np.exp(gamma * x)
    mu = A + alpha * x
    log_pdf  = norm.logpdf(y, loc=mu, scale=sigma_i)
    log_surv = norm.logsf(y_min_arr, loc=mu, scale=sigma_i)
    return -np.sum(log_pdf - log_surv)


def fit_h2_sel_perpoint(x, y, y_min_arr, init=(0.0, 1.5, 0.2, 0.0)):
    """H2 selection-aware fit with per-point y_min. For fraction-based selection."""
    if len(x) < 4:
        return np.nan, np.nan, np.nan, np.nan
    x0 = [init[0], init[1], np.log(init[2]), init[3]]
    r = minimize(neg_loglike_h2_truncated_perpoint, x0=x0, args=(x, y, y_min_arr),
                 method='Nelder-Mead',
                 options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 20000})
    if not r.success:
        return np.nan, np.nan, np.nan, np.nan
    A, alpha, log_sigma0, gamma = r.x
    return A, alpha, np.exp(log_sigma0), gamma

# %% [markdown]
# ## 4 — Sanity check: no selection
#
# Both fits should recover truth when $y_\mathrm{min}$ is far below any data. This validates the machinery before we do anything interesting.

# %%
# Sanity check FIRST runs with constant scatter (gamma=0) to verify backward compatibility.
M, x, y, bin_lab = generate_mock(1000, 1000, M_EDGES_LOW, M_EDGES_HIGH, rng_master, gamma=0.0)
y_min_none = -1e6

Ao, ao, so = fit_ols(x, y)
As, as_, ss = fit_selection_aware(x, y, y_min_none, init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE))

print("== Sanity check 1: constant scatter (gamma=0), no selection ==")
print(f"Truth              A={A_TRUE:+.3f}  alpha={ALPHA_TRUE:.3f}  sigma={SIGMA_TRUE:.3f}")
print(f"OLS                A={Ao:+.3f}  alpha={ao:.3f}  sigma={so:.3f}")
print(f"Selection-aware    A={As:+.3f}  alpha={as_:.3f}  sigma={ss:.3f}")

# Now with the actual GAMMA_SCATTER — fits should recover A, alpha, but sigma_fit
# will land at some effective mean between the low-M and high-M scatter values.
M, x, y, bin_lab = generate_mock(1000, 1000, M_EDGES_LOW, M_EDGES_HIGH, rng_master)  # uses GAMMA_SCATTER default
Ao, ao, so = fit_ols(x, y)
As, as_, ss = fit_selection_aware(x, y, y_min_none, init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE))

print(f"\n== Sanity check 2: mass-dependent scatter (gamma={GAMMA_SCATTER}), no selection ==")
print(f"Truth: A={A_TRUE:+.3f}, alpha={ALPHA_TRUE:.3f}")
print(f"       sigma_lnO(M_piv) = {SIGMA_TRUE:.3f}")
print(f"       sigma_lnO at low bin midpoint  = {sigma_of_M(10**13.85):.3f}")
print(f"       sigma_lnO at high bin midpoint = {sigma_of_M(10**14.85):.3f}")
print(f"OLS                A={Ao:+.3f}  alpha={ao:.3f}  sigma_fit={so:.3f}")
print(f"Selection-aware    A={As:+.3f}  alpha={as_:.3f}  sigma_fit={ss:.3f}")
print("Note: sigma_fit is a single number but truth has different sigma per bin.")
print("      The fit finds some weighted average — this is expected mis-specification.")
# Out:
# == Sanity check 1: constant scatter (gamma=0), no selection ==
# Truth              A=+0.000  alpha=1.500  sigma=0.200
# OLS                A=+0.004  alpha=1.500  sigma=0.199
# Selection-aware    A=+0.004  alpha=1.500  sigma=0.199
#
# == Sanity check 2: mass-dependent scatter (gamma=-0.3), no selection ==
# Truth: A=+0.000, alpha=1.500
#        sigma_lnO(M_piv) = 0.200
#        sigma_lnO at low bin midpoint  = 0.308
#        sigma_lnO at high bin midpoint = 0.155
# OLS                A=-0.002  alpha=1.499  sigma_fit=0.251
# Selection-aware    A=-0.002  alpha=1.499  sigma_fit=0.250
# Note: sigma_fit is a single number but truth has different sigma per bin.
#       The fit finds some weighted average — this is expected mis-specification.

# %% [markdown]
# ## 5 — Diagnostic
#
# One realisation at a threshold that removes a substantial fraction of the low bin. Detected points in **black**, lost points in **red**, three fit lines overlaid: **gold** truth, **navy** OLS on detected only (naïve), **green dashed** selection-aware on detected only.
#
# **What to look for.** The gold truth line should pass through the centroid of the *combined* black + red cloud (i.e. it's the correct mean at each $M$). The navy OLS line is fit only to the black points; its low-mass end will pull upward and its slope will pivot **shallower** than truth. The green dashed selection-aware line, using the same black points but the *correct* truncated likelihood, should sit essentially on top of gold.
#
# *Note on the direction of slope bias.* Your sketch shows the "Incomplete" fit **steeper** than "Full". That geometry arises when selection is applied *within* a narrow mass range so surviving points pivot around their own centroid. With our disjoint two-bin setup, the high-mass bin is essentially untouched by the cut and acts as an anchor, so the pivot goes the *other* way: OLS becomes **shallower**. The magnitude of the bias is the same either way; only the sign flips depending on the geometry.

# %%
# Reproduce the sketch: one realisation, threshold tuned to ~25-30% total loss.
rng_demo = np.random.default_rng(7)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_demo)

Y_MIN_DEMO = -2.1     # roughly f_total ~ 25%
detected = y > Y_MIN_DEMO

Ao, ao, so = fit_ols(x[detected], y[detected])
As, as_, ss = fit_selection_aware(
    x[detected], y[detected], Y_MIN_DEMO,
    init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE),
)

fig, ax = plt.subplots(figsize=(9, 5.5))
# Swapped axes: ln(Obs) on x, log10(M) on y
ax.scatter(y[detected],  np.log10(M[detected]),  c='black', s=25, label='Detected')
ax.scatter(y[~detected], np.log10(M[~detected]), c='red',   s=25, marker='x', label='Lost')

x_grid = np.linspace(x.min() - 0.05, x.max() + 0.05, 100)
logM_grid = np.log10(M_PIV * np.exp(x_grid))
ax.plot(A_TRUE + ALPHA_TRUE * x_grid, logM_grid,
        color='goldenrod', lw=3, label=fr'Truth: $\alpha$={ALPHA_TRUE:.2f}, $\sigma$={SIGMA_TRUE:.2f}')
ax.plot(Ao + ao * x_grid, logM_grid,
        color='navy', lw=2, label=fr'OLS on detected: $\alpha$={ao:.2f}, $\sigma$={so:.2f}')
ax.plot(As + as_ * x_grid, logM_grid,
        color='green', ls='--', lw=2,
        label=fr'Selection-aware: $\alpha$={as_:.2f}, $\sigma$={ss:.2f}')
# Threshold is now a VERTICAL line at y_min
ax.axvline(Y_MIN_DEMO, color='gray', ls=':', lw=1, label=fr'$y_{{\min}}$ = {Y_MIN_DEMO}')

f_low  = 1 - detected[bin_lab==0].mean()
f_high = 1 - detected[bin_lab==1].mean()
f_tot  = 1 - detected.mean()
ax.set_title(fr'Single mock: $f_\mathrm{{low}}$={f_low:.0%}, $f_\mathrm{{high}}$={f_high:.0%}, $f_\mathrm{{total}}$={f_tot:.0%}')
ax.set_xlabel(r'$\ln\,\mathrm{Obs}$')
ax.set_ylabel(r'$\log_{10}(M / [M_\odot / h])$')
ax.legend(loc='lower right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6 — The scan
#
# At each threshold value we draw `n_realizations` fresh mocks, apply the threshold, and run **both** fits on the surviving points. We store $(A_\mathrm{fit}, \alpha_\mathrm{fit}, \sigma_\mathrm{fit})$ and the per-bin incompletenesses for each mock.
#
# The realisation-to-realisation spread at fixed $y_\mathrm{min}$ is our error band on the scan curves. It's a *frequentist* uncertainty — "how much does the point estimate wobble under repeated experiments?" — which is the right question for characterising a fitting procedure. (Bayesian posterior width from a single mock would answer a different question; see the earlier discussion.)

# %%
def scan(y_min_grid, n_realizations, N_low, N_high,
         M_edges_low, M_edges_high,
         seed_offset=0, min_detected=10):
    n_ym = len(y_min_grid)
    keys = ['f_low', 'f_high', 'f_total',
            'A_ols', 'alpha_ols', 'sigma_ols',
            'A_sel', 'alpha_sel', 'sigma_sel']
    results = {k: np.full((n_ym, n_realizations), np.nan) for k in keys}

    for i, y_min in enumerate(y_min_grid):
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng)
            detected = y > y_min

            results['f_low'  ][i, j] = 1 - detected[bin_lab == 0].mean()
            results['f_high' ][i, j] = 1 - detected[bin_lab == 1].mean()
            results['f_total'][i, j] = 1 - detected.mean()

            if detected.sum() < min_detected:
                continue
            xd, yd = x[detected], y[detected]

            Ao, ao, so   = fit_ols(xd, yd)
            As, as_, ss  = fit_selection_aware(
                xd, yd, y_min, init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE))

            results['A_ols'    ][i, j] = Ao
            results['alpha_ols'][i, j] = ao
            results['sigma_ols'][i, j] = so
            results['A_sel'    ][i, j] = As
            results['alpha_sel'][i, j] = as_
            results['sigma_sel'][i, j] = ss

    return results


Y_MIN_GRID     = np.linspace(-3.5, -1.0, 12)
N_REALIZATIONS = 100

results = scan(Y_MIN_GRID, N_REALIZATIONS,
               N_LOW, N_HIGH,
               M_EDGES_LOW, M_EDGES_HIGH,
               seed_offset=1000)
print(f"Scan complete: {len(Y_MIN_GRID)} thresholds x {N_REALIZATIONS} realisations.")
# Out:
# Scan complete: 12 thresholds x 100 realisations.

# %% [markdown]
# ## 7 — Incompleteness table
#
# For each threshold, the mean of $f_\mathrm{low}$, $f_\mathrm{high}$, and $f_\mathrm{total}$ across realisations. Note that $f_\mathrm{high}$ stays essentially at 0 across most of the scan — the wide gap between the bins means a threshold that cuts the low bin is nowhere near the high bin. This is the physically realistic behaviour of a flux-limited survey: it primarily loses the faintest low-mass clusters, and the high-mass end is anchored.

# %%
def summary(arr):
    """mean, 16th, 84th percentiles across realisations for each threshold row."""
    return (np.nanmean(arr, axis=1),
            np.nanpercentile(arr, 16, axis=1),
            np.nanpercentile(arr, 84, axis=1))

f_low_m,  _, _ = summary(results['f_low'])
f_high_m, _, _ = summary(results['f_high'])
f_tot_m,  _, _ = summary(results['f_total'])

print(f"{'y_min':>7} {'f_low':>9} {'f_high':>9} {'f_total':>9}")
for ym, fl, fh, ft in zip(Y_MIN_GRID, f_low_m, f_high_m, f_tot_m):
    print(f"{ym:7.2f} {fl:9.1%} {fh:9.1%} {ft:9.1%}")
# Out:
#   y_min     f_low    f_high   f_total
#   -3.50      0.1%      0.0%      0.0%
#   -3.27      0.5%      0.0%      0.4%
#   -3.05      2.2%      0.0%      1.5%
#   -2.82      7.6%      0.0%      5.1%
#   -2.59     17.1%      0.0%     11.4%
#   -2.36     32.2%      0.0%     21.5%
#   -2.14     51.4%      0.0%     34.3%
#   -1.91     71.0%      0.0%     47.4%
#   -1.68     86.4%      0.0%     57.6%
#   -1.45     95.5%      0.0%     63.7%
#   -1.23     99.0%      0.0%     66.0%
#   -1.00     99.9%      0.0%     66.6%

# %% [markdown]
# ## 8 — Main result: $\sigma$ vs $f_\mathrm{total}$
#
# The plot you asked for. Truth as horizontal reference; OLS in navy, selection-aware in green; shaded bands are the 16–84th percentile across realisations at each threshold.

# %%
s_o_m, s_o_lo, s_o_hi = summary(results['sigma_ols'])
s_s_m, s_s_lo, s_s_hi = summary(results['sigma_sel'])

fig, ax = plt.subplots(figsize=(9, 5.5))
ax.axhline(SIGMA_TRUE, color='goldenrod', ls='--', lw=2,
           label=fr'Truth $\sigma$={SIGMA_TRUE}')

ax.plot(f_tot_m, s_o_m, 'o-', color='navy', lw=2, label='OLS on detected')
ax.fill_between(f_tot_m, s_o_lo, s_o_hi, color='navy', alpha=0.2)

ax.plot(f_tot_m, s_s_m, 's-', color='green', lw=2, label='Selection-aware MLE')
ax.fill_between(f_tot_m, s_s_lo, s_s_hi, color='green', alpha=0.2)

ax.set_xlabel(r'$f_\mathrm{total}$ (fraction of clusters lost)')
ax.set_ylabel(r'Fitted $\sigma_{\ln\,\mathrm{Obs}}$')
ax.set_title('Recovered intrinsic scatter vs total incompleteness')
ax.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9 — Companion panels: $\alpha$ and $A$ vs $f_\mathrm{total}$
#
# In this two-bin geometry, the **slope** and **intercept** are the more visibly biased quantities — the wide mass lever arm gives the naïve fit a lot of room to pivot. This is a useful teaching point: $\sigma$ isn't necessarily the most sensitive diagnostic of selection bias in scaling relations; the mean relation itself is.

# %%
a_o_m, a_o_lo, a_o_hi = summary(results['alpha_ols'])
a_s_m, a_s_lo, a_s_hi = summary(results['alpha_sel'])
A_o_m, A_o_lo, A_o_hi = summary(results['A_ols'])
A_s_m, A_s_lo, A_s_hi = summary(results['A_sel'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4.8))

ax1.axhline(ALPHA_TRUE, color='goldenrod', ls='--', lw=2, label=fr'Truth $\alpha$={ALPHA_TRUE}')
ax1.plot(f_tot_m, a_o_m, 'o-', color='navy', lw=2, label='OLS')
ax1.fill_between(f_tot_m, a_o_lo, a_o_hi, color='navy', alpha=0.2)
ax1.plot(f_tot_m, a_s_m, 's-', color='green', lw=2, label='Selection-aware')
ax1.fill_between(f_tot_m, a_s_lo, a_s_hi, color='green', alpha=0.2)
ax1.set_xlabel(r'$f_\mathrm{total}$')
ax1.set_ylabel(r'Fitted slope $\alpha$')
ax1.set_title('Slope')
ax1.legend()

ax2.axhline(A_TRUE, color='goldenrod', ls='--', lw=2, label=fr'Truth $A$={A_TRUE}')
ax2.plot(f_tot_m, A_o_m, 'o-', color='navy', lw=2, label='OLS')
ax2.fill_between(f_tot_m, A_o_lo, A_o_hi, color='navy', alpha=0.2)
ax2.plot(f_tot_m, A_s_m, 's-', color='green', lw=2, label='Selection-aware')
ax2.fill_between(f_tot_m, A_s_lo, A_s_hi, color='green', alpha=0.2)
ax2.set_xlabel(r'$f_\mathrm{total}$')
ax2.set_ylabel(r'Fitted intercept $A$')
ax2.set_title('Intercept')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10 — Alternative selection: bin-wise fraction loss
#
# The threshold-based selection above is what a real flux-limited survey approximates. But it has a limitation for our study: with a wide bin gap, a single $y_\mathrm{min}$ that meaningfully affects the low bin barely touches the high bin (the $f_\mathrm{high}$ column stayed at 0% throughout). We never got to see what happens when *both* bins lose clusters simultaneously.
#
# The fraction-based alternative: within each bin, remove the lowest-observable fraction $f_\mathrm{low}$ (low bin) and $f_\mathrm{high}$ (high bin). This is *rank-based* selection: sort by $y$, cut the bottom $f$. In real analyses, this would correspond to knowing your completeness function well enough to say "we're 80% complete in this bin, 90% in that bin" — which happens after an injection–recovery calibration exercise.
#
# **Default ratio.** From our earlier discussion: $f_\mathrm{low} : f_\mathrm{high} = 2 : 1$, so at each scan point $f_\mathrm{high} = f_\mathrm{low}/2$. This encodes the expectation that lower-mass, fainter clusters are always harder to detect. We scan $f_\mathrm{low} \in [0, 0.5]$, giving $f_\mathrm{total} \in [0, 37.5\%]$ (weighted average with equal $N$ per bin).
#
# **Selection-aware fit under fraction selection.** Fraction selection is equivalent to a *bin-dependent* threshold: within bin $k$, the effective $y_\mathrm{min}^{(k)}$ is the observable value of the lowest-$y$ surviving cluster in that bin. So the truncated-Gaussian likelihood generalises to
# $$-\ln \mathcal{L}(A, \alpha, \sigma) = -\sum_i \left[ \ln \phi\!\left(\tfrac{y_i - A - \alpha x_i}{\sigma}\right) - \ln \sigma - \ln P(y > y_\mathrm{min}^{(k_i)} \mid x_i) \right]$$
#
# where $k_i$ is the bin of point $i$. We just pass a *per-point* $y_\mathrm{min}$ array to `norm.logsf`.
#
# *Caveat.* Using the empirical $y_\mathrm{min}$ from the same mock as the fit is slightly circular — in a real analysis you'd measure completeness from external injection tests, not from the sample itself. For the pedagogy here it's fine; the answer converges to the "true" bin-dependent threshold as $N$ grows.

# %%
def fraction_based_selection(y, bin_lab, f_low, f_high):
    """Remove the lowest-y f_low fraction from bin 0, f_high from bin 1.

    Returns:
        detected : bool array of survivors
        (y_min_low, y_min_high) : empirical thresholds per bin (=y of lowest survivor)
    """
    detected = np.ones(len(y), dtype=bool)
    y_min_per_bin = [-np.inf, -np.inf]

    for k, f in [(0, f_low), (1, f_high)]:
        idx = np.where(bin_lab == k)[0]
        if len(idx) == 0 or f <= 0:
            continue
        n_remove = int(round(f * len(idx)))
        if n_remove == 0:
            continue
        if n_remove >= len(idx):
            detected[idx] = False
            continue
        order = np.argsort(y[idx])
        detected[idx[order[:n_remove]]] = False
        y_min_per_bin[k] = y[idx[order[n_remove:]]].min()

    return detected, tuple(y_min_per_bin)


def neg_loglike_truncated_perpoint(params, x, y, y_min_arr):
    """Truncated-Gaussian negative log-likelihood with a per-point y_min."""
    A, alpha, log_sigma = params
    sigma = np.exp(log_sigma)
    mu = A + alpha * x
    log_pdf  = norm.logpdf(y, loc=mu, scale=sigma)
    log_surv = norm.logsf(y_min_arr, loc=mu, scale=sigma)
    return -np.sum(log_pdf - log_surv)


def fit_selection_aware_perpoint(x, y, y_min_arr, init=(0.0, 1.5, 0.2)):
    if len(x) < 3:
        return np.nan, np.nan, np.nan
    x0 = [init[0], init[1], np.log(init[2])]
    r = minimize(
        neg_loglike_truncated_perpoint, x0=x0, args=(x, y, y_min_arr),
        method='Nelder-Mead',
        options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 10000},
    )
    if not r.success:
        return np.nan, np.nan, np.nan
    A, alpha, log_sigma = r.x
    return A, alpha, np.exp(log_sigma)

# %% [markdown]
# ### Diagnostic: single mock under fraction-based selection
#
# One realisation at $(f_\mathrm{low}, f_\mathrm{high}) = (30\%, 15\%)$. Both bins now lose their faintest clusters, and both bin centroids get pulled up (unlike the threshold case, where only the low bin was affected). What to look for: the OLS line's *intercept* is more strongly biased than its slope here, because both bins pivot upward together.

# %%
rng_demo2 = np.random.default_rng(11)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_demo2)

F_LOW_DEMO  = 0.30
F_HIGH_DEMO = 0.15
detected, (ym_lo, ym_hi) = fraction_based_selection(y, bin_lab, F_LOW_DEMO, F_HIGH_DEMO)

Ao, ao, so = fit_ols(x[detected], y[detected])
y_min_arr = np.where(bin_lab[detected] == 0, ym_lo, ym_hi)
As, as_, ss = fit_selection_aware_perpoint(
    x[detected], y[detected], y_min_arr,
    init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE),
)

fig, ax = plt.subplots(figsize=(9, 5.5))
ax.scatter(y[detected],  np.log10(M[detected]),  c='black', s=25, label='Detected')
ax.scatter(y[~detected], np.log10(M[~detected]), c='red', s=25, marker='x', label='Lost')

x_grid = np.linspace(x.min() - 0.05, x.max() + 0.05, 100)
logM_grid = np.log10(M_PIV * np.exp(x_grid))
ax.plot(A_TRUE + ALPHA_TRUE * x_grid, logM_grid,
        color='goldenrod', lw=3, label=fr'Truth: $\alpha$={ALPHA_TRUE:.2f}, $\sigma$={SIGMA_TRUE:.2f}')
ax.plot(Ao + ao * x_grid, logM_grid,
        color='navy', lw=2, label=fr'OLS on detected: $\alpha$={ao:.2f}, $\sigma$={so:.2f}')
ax.plot(As + as_ * x_grid, logM_grid,
        color='green', ls='--', lw=2,
        label=fr'Selection-aware: $\alpha$={as_:.2f}, $\sigma$={ss:.2f}')

# Per-bin thresholds are now VERTICAL lines
ax.axvline(ym_lo, color='gray', ls=':', lw=1, alpha=0.7,
           label=fr'$y_{{\min}}^{{\mathrm{{low}}}}$ = {ym_lo:.2f}')
ax.axvline(ym_hi, color='gray', ls='-.', lw=1, alpha=0.7,
           label=fr'$y_{{\min}}^{{\mathrm{{high}}}}$ = {ym_hi:.2f}')

f_tot_demo = 1 - detected.mean()
ax.set_title(fr'Fraction-based mock: $f_\mathrm{{low}}$={F_LOW_DEMO:.0%}, $f_\mathrm{{high}}$={F_HIGH_DEMO:.0%}, $f_\mathrm{{total}}$={f_tot_demo:.0%}')
ax.set_xlabel(r'$\ln\,\mathrm{Obs}$')
ax.set_ylabel(r'$\log_{10}(M / [M_\odot / h])$')
ax.legend(loc='lower right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fraction-based scan
#
# Same structure as the threshold scan: scan the loss fraction, run many realisations, record OLS and selection-aware fits. Here the scan variable is $f_\mathrm{low}$ with $f_\mathrm{high} = f_\mathrm{low} / 2$.

# %%
def scan_fraction(f_low_grid, ratio, n_realizations, N_low, N_high,
                  M_edges_low, M_edges_high,
                  seed_offset=2000, min_detected=10):
    """Scan fraction-based selection. f_high = ratio * f_low at each step."""
    n = len(f_low_grid)
    keys = ['f_low', 'f_high', 'f_total',
            'A_ols', 'alpha_ols', 'sigma_ols',
            'A_sel', 'alpha_sel', 'sigma_sel']
    results = {k: np.full((n, n_realizations), np.nan) for k in keys}

    for i, fl in enumerate(f_low_grid):
        fh = ratio * fl
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng)
            det, (ym_lo, ym_hi) = fraction_based_selection(y, bin_lab, fl, fh)

            results['f_low'  ][i, j] = 1 - det[bin_lab == 0].mean()
            results['f_high' ][i, j] = 1 - det[bin_lab == 1].mean()
            results['f_total'][i, j] = 1 - det.mean()

            if det.sum() < min_detected:
                continue

            xd, yd = x[det], y[det]
            Ao, ao, so = fit_ols(xd, yd)

            y_min_arr = np.where(bin_lab[det] == 0, ym_lo, ym_hi)
            As, as_, ss = fit_selection_aware_perpoint(
                xd, yd, y_min_arr,
                init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE),
            )

            results['A_ols'    ][i, j] = Ao
            results['alpha_ols'][i, j] = ao
            results['sigma_ols'][i, j] = so
            results['A_sel'    ][i, j] = As
            results['alpha_sel'][i, j] = as_
            results['sigma_sel'][i, j] = ss

    return results


F_LOW_GRID = np.linspace(0.0, 0.5, 11)
RATIO_HIGH_OVER_LOW = 0.5   # f_high = 0.5 * f_low
results_frac = scan_fraction(
    F_LOW_GRID, RATIO_HIGH_OVER_LOW, N_REALIZATIONS,
    N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
    seed_offset=2000,
)
print(f"Fraction scan complete: {len(F_LOW_GRID)} f_low values x {N_REALIZATIONS} realisations.")

# Table
f_low_fm, _, _  = summary(results_frac['f_low'])
f_high_fm, _, _ = summary(results_frac['f_high'])
f_tot_fm, _, _  = summary(results_frac['f_total'])
print(f"\n{'f_low set':>10} {'f_low real':>11} {'f_high real':>12} {'f_total':>9}")
for fl_set, fl, fh, ft in zip(F_LOW_GRID, f_low_fm, f_high_fm, f_tot_fm):
    print(f"{fl_set:10.2f} {fl:11.1%} {fh:12.1%} {ft:9.1%}")
# Out:
# Fraction scan complete: 11 f_low values x 100 realisations.
#
#  f_low set  f_low real  f_high real   f_total
#       0.00        0.0%         0.0%      0.0%
#       0.05        5.0%         2.0%      4.0%
#       0.10       10.0%         4.0%      8.0%
#       0.15       15.0%         8.0%     12.7%
#       0.20       20.0%        10.0%     16.7%
#       0.25       25.0%        12.0%     20.7%
#       0.30       30.0%        16.0%     25.3%
#       0.35       35.0%        18.0%     29.3%
#       0.40       40.0%        20.0%     33.3%
#       0.45       45.0%        22.0%     37.3%
#       0.50       50.0%        24.0%     41.3%

# %% [markdown]
# ### Results under fraction-based selection
#
# Same three panels ($\sigma$, $\alpha$, $A$ vs $f_\mathrm{total}$), now with truncation in both bins.

# %%
s_o_fm, s_o_flo, s_o_fhi = summary(results_frac['sigma_ols'])
s_s_fm, s_s_flo, s_s_fhi = summary(results_frac['sigma_sel'])
a_o_fm, a_o_flo, a_o_fhi = summary(results_frac['alpha_ols'])
a_s_fm, a_s_flo, a_s_fhi = summary(results_frac['alpha_sel'])
A_o_fm, A_o_flo, A_o_fhi = summary(results_frac['A_ols'])
A_s_fm, A_s_flo, A_s_fhi = summary(results_frac['A_sel'])

fig, ax = plt.subplots(figsize=(9, 5.5))
ax.axhline(SIGMA_TRUE, color='goldenrod', ls='--', lw=2, label=fr'Truth $\sigma$={SIGMA_TRUE}')
ax.plot(f_tot_fm, s_o_fm, 'o-', color='navy', lw=2, label='OLS on detected')
ax.fill_between(f_tot_fm, s_o_flo, s_o_fhi, color='navy', alpha=0.2)
ax.plot(f_tot_fm, s_s_fm, 's-', color='green', lw=2, label='Selection-aware MLE')
ax.fill_between(f_tot_fm, s_s_flo, s_s_fhi, color='green', alpha=0.2)
ax.set_xlabel(r'$f_\mathrm{total}$ (fraction of clusters lost)')
ax.set_ylabel(r'Fitted $\sigma_{\ln\,\mathrm{Obs}}$')
ax.set_title(r'Fraction-based selection: $\sigma$ vs $f_\mathrm{total}$')
ax.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4.8))

ax1.axhline(ALPHA_TRUE, color='goldenrod', ls='--', lw=2, label=fr'Truth $\alpha$={ALPHA_TRUE}')
ax1.plot(f_tot_fm, a_o_fm, 'o-', color='navy', lw=2, label='OLS')
ax1.fill_between(f_tot_fm, a_o_flo, a_o_fhi, color='navy', alpha=0.2)
ax1.plot(f_tot_fm, a_s_fm, 's-', color='green', lw=2, label='Selection-aware')
ax1.fill_between(f_tot_fm, a_s_flo, a_s_fhi, color='green', alpha=0.2)
ax1.set_xlabel(r'$f_\mathrm{total}$')
ax1.set_ylabel(r'Fitted slope $\alpha$')
ax1.set_title('Slope (fraction-based)')
ax1.legend()

ax2.axhline(A_TRUE, color='goldenrod', ls='--', lw=2, label=fr'Truth $A$={A_TRUE}')
ax2.plot(f_tot_fm, A_o_fm, 'o-', color='navy', lw=2, label='OLS')
ax2.fill_between(f_tot_fm, A_o_flo, A_o_fhi, color='navy', alpha=0.2)
ax2.plot(f_tot_fm, A_s_fm, 's-', color='green', lw=2, label='Selection-aware')
ax2.fill_between(f_tot_fm, A_s_flo, A_s_fhi, color='green', alpha=0.2)
ax2.set_xlabel(r'$f_\mathrm{total}$')
ax2.set_ylabel(r'Fitted intercept $A$')
ax2.set_title('Intercept (fraction-based)')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Side-by-side: threshold vs fraction
#
# Same $\sigma$ axis, both selection styles, so the geometric contrast is direct.

# %%
fig, (axL, axR) = plt.subplots(1, 2, figsize=(13, 4.8), sharey=True)

axL.axhline(SIGMA_TRUE, color='goldenrod', ls='--', lw=2, label=f'Truth ({SIGMA_TRUE})')
axL.plot(f_tot_m, s_o_m, 'o-', color='navy', lw=2, label='OLS')
axL.fill_between(f_tot_m, s_o_lo, s_o_hi, color='navy', alpha=0.2)
axL.plot(f_tot_m, s_s_m, 's-', color='green', lw=2, label='Selection-aware')
axL.fill_between(f_tot_m, s_s_lo, s_s_hi, color='green', alpha=0.2)
axL.set_xlabel(r'$f_\mathrm{total}$')
axL.set_ylabel(r'Fitted $\sigma_{\ln\,\mathrm{Obs}}$')
axL.set_title('Threshold-based selection')
axL.legend()

axR.axhline(SIGMA_TRUE, color='goldenrod', ls='--', lw=2, label=f'Truth ({SIGMA_TRUE})')
axR.plot(f_tot_fm, s_o_fm, 'o-', color='navy', lw=2, label='OLS')
axR.fill_between(f_tot_fm, s_o_flo, s_o_fhi, color='navy', alpha=0.2)
axR.plot(f_tot_fm, s_s_fm, 's-', color='green', lw=2, label='Selection-aware')
axR.fill_between(f_tot_fm, s_s_flo, s_s_fhi, color='green', alpha=0.2)
axR.set_xlabel(r'$f_\mathrm{total}$')
axR.set_title(r'Fraction-based selection ($f_\mathrm{high}=f_\mathrm{low}/2$)')
axR.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11 — Null test: observable-independent random loss
#
# The threshold-based and fraction-based scans both bias the fit because *which* clusters are lost depends on the observable — low-$y$ clusters go first. If we remove a random fraction of clusters *without* looking at their observable value, there should be no bias: a random subset of a fair sample is still a fair sample. This section confirms that expectation.
#
# **Why bother running the null test.** Without it, someone reading the notebook could reasonably ask: "How do we know the biases in Sections 9 and 10 come from the observable-dependent nature of the selection, and not from just having fewer clusters to fit?" The random-loss scan is the answer. It removes the same total fraction of clusters — just picked uniformly at random — and shows that OLS and MLE both recover truth. That difference is what isolates the *selection effect* from the *sample-size effect*.
#
# **Fit setup.** Under known random selection, the survival probability $P(\text{detected} \mid y, x)$ is a bin-dependent *constant* — it does not depend on $(A, \alpha, \sigma)$. In the likelihood, $-\ln P(\text{survival})$ becomes an additive constant per point and drops out of the MLE. So the "correct" selection-aware fit here is just untruncated Gaussian MLE, which we get by calling `fit_selection_aware` with $y_\mathrm{min} \to -\infty$ (implemented as a large negative number). This is a genuine null test of the whole fitting machinery.
#
# **Real-world analogue.** Purely random loss doesn't quite happen in nature, but it's a decent proxy for *misidentification* or *catalogue-cleaning* losses — e.g. spectroscopic follow-up failed for random 15% of X-ray candidates, or a random fraction of clusters were flagged for known artefacts. What matters is that the loss cause is uncorrelated with the observable used for the fit.

# %%
def random_selection(y, bin_lab, f_low, f_high, rng):
    """Randomly remove f_low fraction from bin 0, f_high from bin 1.
    Selection is INDEPENDENT of the observable — this is the null test.
    """
    detected = np.ones(len(y), dtype=bool)
    for k, f in [(0, f_low), (1, f_high)]:
        idx = np.where(bin_lab == k)[0]
        if len(idx) == 0 or f <= 0:
            continue
        n_remove = int(round(f * len(idx)))
        if n_remove == 0:
            continue
        if n_remove >= len(idx):
            detected[idx] = False
            continue
        to_remove = rng.choice(idx, size=n_remove, replace=False)
        detected[to_remove] = False
    return detected

# %% [markdown]
# ### Diagnostic: single mock under random loss
#
# At $(f_\mathrm{low}, f_\mathrm{high}) = (30\%, 15\%)$, the same total loss as the fraction-based demo. The visual signature of random loss: red X's are scattered *throughout* the observable range within each bin, not clustered at the left. There is no vertical threshold line — that's the point.

# %%
rng_demo3 = np.random.default_rng(23)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_demo3)

F_LOW_DEMO  = 0.30
F_HIGH_DEMO = 0.15
detected = random_selection(y, bin_lab, F_LOW_DEMO, F_HIGH_DEMO, rng_demo3)

Ao, ao, so = fit_ols(x[detected], y[detected])
# Under known random selection, no truncation — pass y_min = -infinity
As, as_, ss = fit_selection_aware(
    x[detected], y[detected], -1e6,
    init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE),
)

fig, ax = plt.subplots(figsize=(9, 5.5))
ax.scatter(y[detected],  np.log10(M[detected]),  c='black', s=25, label='Detected')
ax.scatter(y[~detected], np.log10(M[~detected]), c='red', s=25, marker='x', label='Lost')

x_grid = np.linspace(x.min() - 0.05, x.max() + 0.05, 100)
logM_grid = np.log10(M_PIV * np.exp(x_grid))
ax.plot(A_TRUE + ALPHA_TRUE * x_grid, logM_grid,
        color='goldenrod', lw=3, label=fr'Truth: $\alpha$={ALPHA_TRUE:.2f}, $\sigma$={SIGMA_TRUE:.2f}')
ax.plot(Ao + ao * x_grid, logM_grid,
        color='navy', lw=2, label=fr'OLS on detected: $\alpha$={ao:.2f}, $\sigma$={so:.2f}')
ax.plot(As + as_ * x_grid, logM_grid,
        color='green', ls='--', lw=2,
        label=fr'Untruncated MLE: $\alpha$={as_:.2f}, $\sigma$={ss:.2f}')

f_tot_demo = 1 - detected.mean()
ax.set_title(fr'Random-loss null test: $f_\mathrm{{low}}$={F_LOW_DEMO:.0%}, $f_\mathrm{{high}}$={F_HIGH_DEMO:.0%}, $f_\mathrm{{total}}$={f_tot_demo:.0%}')
ax.set_xlabel(r'$\ln\,\mathrm{Obs}$')
ax.set_ylabel(r'$\log_{10}(M / [M_\odot / h])$')
ax.legend(loc='lower right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Random-loss scan
#
# Same $f_\mathrm{low}$ grid and 2:1 ratio as the fraction-based scan, so the three scans (threshold-based, fraction-based, random) all cover comparable $f_\mathrm{total}$ ranges. Expected result: all three parameter curves stay flat at truth throughout, both fits agree, within realisation bands.

# %%
def scan_random(f_low_grid, ratio, n_realizations, N_low, N_high,
                M_edges_low, M_edges_high,
                seed_offset=3000, min_detected=10):
    n = len(f_low_grid)
    keys = ['f_low', 'f_high', 'f_total',
            'A_ols', 'alpha_ols', 'sigma_ols',
            'A_sel', 'alpha_sel', 'sigma_sel']
    results = {k: np.full((n, n_realizations), np.nan) for k in keys}

    for i, fl in enumerate(f_low_grid):
        fh = ratio * fl
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng)
            det = random_selection(y, bin_lab, fl, fh, rng)

            results['f_low'  ][i, j] = 1 - det[bin_lab == 0].mean()
            results['f_high' ][i, j] = 1 - det[bin_lab == 1].mean()
            results['f_total'][i, j] = 1 - det.mean()

            if det.sum() < min_detected:
                continue

            xd, yd = x[det], y[det]
            Ao, ao, so = fit_ols(xd, yd)
            As, as_, ss = fit_selection_aware(
                xd, yd, -1e6, init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE))

            results['A_ols'    ][i, j] = Ao
            results['alpha_ols'][i, j] = ao
            results['sigma_ols'][i, j] = so
            results['A_sel'    ][i, j] = As
            results['alpha_sel'][i, j] = as_
            results['sigma_sel'][i, j] = ss

    return results


results_rand = scan_random(
    F_LOW_GRID, RATIO_HIGH_OVER_LOW, N_REALIZATIONS,
    N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
    seed_offset=3000,
)
print(f"Random-loss scan complete: {len(F_LOW_GRID)} f_low values x {N_REALIZATIONS} realisations.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 40
#      35             results['sigma_sel'][i, j] = ss
#      37     return results
# ---> 40 results_rand = scan_random(
#      41     F_LOW_GRID, RATIO_HIGH_OVER_LOW, N_REALIZATIONS,
#      42     N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
#      43     seed_offset=3000,
#      44 )
#      45 print(f"Random-loss scan complete: {len(F_LOW_GRID)} f_low values x {N_REALIZATIONS} realisations.")
#
# Cell In[18], line 27, in scan_random(f_low_grid, ratio, n_realizations, N_low, N_high, M_edges_low, M_edges_high, seed_offset, min_detected)
#      25 xd, yd = x[det], y[det]
#      26 Ao, ao, so = fit_ols(xd, yd)
# ---> 27 As, as_, ss = fit_selection_aware(
#      28     xd, yd, -1e6, init=(A_TRUE, ALPHA_TRUE, SIGMA_TRUE))
#      30 results['A_ols'    ][i, j] = Ao
#      31 results['alpha_ols'][i, j] = ao
#
# Cell In[3], line 26, in fit_selection_aware(x, y, y_min, init)
#      24     return np.nan, np.nan, np.nan
#      25 x0 = [init[0], init[1], np.log(init[2])]
# ---> 26 result = minimize(
#      27     neg_loglike_truncated, x0=x0, args=(x, y, y_min),
#      28     method='Nelder-Mead',
#      29     options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 10000},
#      30 )
#      31 if not result.success:
#      32     return np.nan, np.nan, np.nan
#
# File ~/envs/analysis/lib/python3.9/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/envs/analysis/lib/python3.9/site-packages/scipy/optimize/_optimize.py:880, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     878 if bounds is not None:
#     879     xcc = np.clip(xcc, lower_bound, upper_bound)
# --> 880 fxcc = func(xcc)
#     882 if fxcc < fsim[-1]:
#     883     sim[-1] = xcc
#
# File ~/envs/analysis/lib/python3.9/site-packages/scipy/optimize/_optimize.py:526, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     524 ncalls[0] += 1
#     525 # A copy of x is sent to the user function (gh13740)
# --> 526 fx = function(np.copy(x), *(wrapper_args + args))
#     527 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     528 # backwards-compatibility, also allow np.array([1.3]),
#     529 # np.array([[1.3]]) etc.
#     530 if not np.isscalar(fx):
#
# Cell In[3], line 16, in neg_loglike_truncated(params, x, y, y_min)
#      14 sigma = np.exp(log_sigma)
#      15 mu = A + alpha * x
# ---> 16 log_pdf  = norm.logpdf(y, loc=mu, scale=sigma)
#      17 log_surv = norm.logsf(y_min, loc=mu, scale=sigma)  # ln P(y > y_min | x)
#      18 return -np.sum(log_pdf - log_surv)
#
# KeyboardInterrupt:

# %%
f_tot_rm, _, _  = summary(results_rand['f_total'])
s_o_rm, s_o_rlo, s_o_rhi = summary(results_rand['sigma_ols'])
s_s_rm, s_s_rlo, s_s_rhi = summary(results_rand['sigma_sel'])
a_o_rm, a_o_rlo, a_o_rhi = summary(results_rand['alpha_ols'])
a_s_rm, a_s_rlo, a_s_rhi = summary(results_rand['alpha_sel'])
A_o_rm, A_o_rlo, A_o_rhi = summary(results_rand['A_ols'])
A_s_rm, A_s_rlo, A_s_rhi = summary(results_rand['A_sel'])

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4.5))

for ax, (o_m, o_lo, o_hi), (s_m, s_lo, s_hi), truth, ylabel, title in [
    (ax1, (s_o_rm, s_o_rlo, s_o_rhi), (s_s_rm, s_s_rlo, s_s_rhi),
     SIGMA_TRUE, r'Fitted $\sigma_{\ln\,\mathrm{Obs}}$', 'Scatter'),
    (ax2, (a_o_rm, a_o_rlo, a_o_rhi), (a_s_rm, a_s_rlo, a_s_rhi),
     ALPHA_TRUE, r'Fitted slope $\alpha$', 'Slope'),
    (ax3, (A_o_rm, A_o_rlo, A_o_rhi), (A_s_rm, A_s_rlo, A_s_rhi),
     A_TRUE, r'Fitted intercept $A$', 'Intercept'),
]:
    ax.axhline(truth, color='goldenrod', ls='--', lw=2, label=f'Truth ({truth})')
    ax.plot(f_tot_rm, o_m, 'o-', color='navy', lw=2, label='OLS')
    ax.fill_between(f_tot_rm, o_lo, o_hi, color='navy', alpha=0.2)
    ax.plot(f_tot_rm, s_m, 's-', color='green', lw=2, label='Untruncated MLE')
    ax.fill_between(f_tot_rm, s_lo, s_hi, color='green', alpha=0.2)
    ax.set_xlabel(r'$f_\mathrm{total}$')
    ax.set_ylabel(ylabel)
    ax.set_title(f'{title} (random loss)')
    ax.legend(fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12 — H1 vs H2: mis-specifying the scatter model
#
# The scatter is now mass-dependent by construction (γ = −0.3). Two hypotheses about what a real analyst would do:
#
# **H1 — "we don't know it's mass-dependent."** Fit assuming constant σ. Three free parameters: (A, α, σ). The model is *structurally mis-specified*: no single σ can describe truth that has different scatter in the two bins.
#
# **H2 — "we know it's a power law in mass, but we don't know σ_0 or γ."** Fit with σ_i = σ_0 · (M_i/M_piv)^γ. Four free parameters: (A, α, σ_0, γ). The model is *correctly specified*.
#
# Each hypothesis gets two selection treatments: OLS-style (no truncation modelled) and selection-aware (truncation modelled). That gives four fits per mock:
#
# | Fit | Scatter model | Selection model |
# |---|---|---|
# | **H1-OLS** | constant σ | none — assumes fair sample |
# | **H1-Sel** | constant σ | truncated Gaussian |
# | **H2-MLE** | mass-dep σ | none |
# | **H2-Sel** | mass-dep σ | truncated Gaussian |
#
# **What we expect.** H2-Sel (both correct) should recover truth. H1-OLS (both wrong) should show the strongest bias. H1-Sel and H2-MLE isolate the cost of getting *only one* piece wrong — and the interesting question is whether they give comparable biases, or whether one type of mis-specification is worse than the other.
#
# This is the toy analogue of running your pipeline in `wrong-fixed` mode (γ_model = 0 but γ_data ≠ 0) vs `free` mode (γ_model floated).

# %% [markdown]
# ### Scenario 1: threshold-based selection
#
# Single global $y_\mathrm{min}$. The correct selection-aware likelihood uses a single truncation term per point.

# %%
def scan_h1h2(y_min_grid, n_realizations, N_low, N_high,
              M_edges_low, M_edges_high, gamma_truth=GAMMA_SCATTER,
              seed_offset=6000, min_detected=10):
    """Run all 4 fits (H1-OLS, H1-Sel, H2-MLE, H2-Sel) across the threshold grid.
    Mocks are generated with mass-dependent scatter (gamma=gamma_truth).
    """
    n_ym = len(y_min_grid)
    keys = ['f_low', 'f_high', 'f_total',
            'A_h1o', 'a_h1o', 's_h1o',
            'A_h1s', 'a_h1s', 's_h1s',
            'A_h2m', 'a_h2m', 's_h2m', 'g_h2m',
            'A_h2s', 'a_h2s', 's_h2s', 'g_h2s']
    results = {k: np.full((n_ym, n_realizations), np.nan) for k in keys}

    init_h1 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE)
    init_h2 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE, gamma_truth)

    for i, y_min in enumerate(y_min_grid):
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng,
                                             gamma=gamma_truth)
            det = y > y_min
            results['f_low'  ][i, j] = 1 - det[bin_lab == 0].mean()
            results['f_high' ][i, j] = 1 - det[bin_lab == 1].mean()
            results['f_total'][i, j] = 1 - det.mean()
            if det.sum() < min_detected:
                continue
            xd, yd = x[det], y[det]

            Ao, ao, so = fit_ols(xd, yd)
            Ah1, ah1, sh1 = fit_selection_aware(xd, yd, y_min, init=init_h1)
            Ah2m, ah2m, s0h2m, gh2m = fit_h2_untrunc(xd, yd, init=init_h2)
            Ah2s, ah2s, s0h2s, gh2s = fit_h2_sel(xd, yd, y_min, init=init_h2)

            results['A_h1o'][i,j], results['a_h1o'][i,j], results['s_h1o'][i,j] = Ao, ao, so
            results['A_h1s'][i,j], results['a_h1s'][i,j], results['s_h1s'][i,j] = Ah1, ah1, sh1
            results['A_h2m'][i,j], results['a_h2m'][i,j], results['s_h2m'][i,j], results['g_h2m'][i,j] = Ah2m, ah2m, s0h2m, gh2m
            results['A_h2s'][i,j], results['a_h2s'][i,j], results['s_h2s'][i,j], results['g_h2s'][i,j] = Ah2s, ah2s, s0h2s, gh2s
    return results

results_h1h2 = scan_h1h2(Y_MIN_GRID, N_REALIZATIONS,
                         N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
                         gamma_truth=GAMMA_SCATTER, seed_offset=6000)
print(f"H1 vs H2 scan complete: {len(Y_MIN_GRID)} thresholds x {N_REALIZATIONS} realisations x 4 fits.")
# Out:
# H1 vs H2 scan complete: 12 thresholds x 100 realisations x 4 fits.

# %% [markdown]
# ### Scenario 2: fraction-based selection
#
# Per-bin loss fraction ($f_\mathrm{low} = 2 \times f_\mathrm{high}$). The correct selection-aware likelihood uses a per-point $y_\mathrm{min}$ equal to the empirical bin threshold (lowest surviving $y$ in that bin), matching the machinery from Section 10.

# %%
def scan_h1h2_fraction(f_low_grid, ratio, n_realizations, N_low, N_high,
                       M_edges_low, M_edges_high, gamma_truth=GAMMA_SCATTER,
                       seed_offset=7000, min_detected=10):
    """Same 4 fits as scan_h1h2, but under fraction-based selection.
    f_high = ratio * f_low at each scan point.
    """
    n = len(f_low_grid)
    keys = ['f_low', 'f_high', 'f_total',
            'A_h1o', 'a_h1o', 's_h1o',
            'A_h1s', 'a_h1s', 's_h1s',
            'A_h2m', 'a_h2m', 's_h2m', 'g_h2m',
            'A_h2s', 'a_h2s', 's_h2s', 'g_h2s']
    results = {k: np.full((n, n_realizations), np.nan) for k in keys}

    init_h1 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE)
    init_h2 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE, gamma_truth)

    for i, fl in enumerate(f_low_grid):
        fh = ratio * fl
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng,
                                             gamma=gamma_truth)
            det, (ym_lo, ym_hi) = fraction_based_selection(y, bin_lab, fl, fh)

            results['f_low'  ][i, j] = 1 - det[bin_lab == 0].mean()
            results['f_high' ][i, j] = 1 - det[bin_lab == 1].mean()
            results['f_total'][i, j] = 1 - det.mean()
            if det.sum() < min_detected:
                continue

            xd, yd = x[det], y[det]
            y_min_arr = np.where(bin_lab[det] == 0, ym_lo, ym_hi)

            Ao, ao, so                  = fit_ols(xd, yd)
            Ah1, ah1, sh1               = fit_selection_aware_perpoint(xd, yd, y_min_arr, init=init_h1)
            Ah2m, ah2m, s0h2m, gh2m     = fit_h2_untrunc(xd, yd, init=init_h2)
            Ah2s, ah2s, s0h2s, gh2s     = fit_h2_sel_perpoint(xd, yd, y_min_arr, init=init_h2)

            results['A_h1o'][i,j], results['a_h1o'][i,j], results['s_h1o'][i,j] = Ao, ao, so
            results['A_h1s'][i,j], results['a_h1s'][i,j], results['s_h1s'][i,j] = Ah1, ah1, sh1
            results['A_h2m'][i,j], results['a_h2m'][i,j], results['s_h2m'][i,j], results['g_h2m'][i,j] = Ah2m, ah2m, s0h2m, gh2m
            results['A_h2s'][i,j], results['a_h2s'][i,j], results['s_h2s'][i,j], results['g_h2s'][i,j] = Ah2s, ah2s, s0h2s, gh2s
    return results


results_h1h2_frac = scan_h1h2_fraction(
    F_LOW_GRID, RATIO_HIGH_OVER_LOW, N_REALIZATIONS,
    N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
    gamma_truth=GAMMA_SCATTER, seed_offset=7000,
)
print(f"Fraction H1/H2 scan complete: {len(F_LOW_GRID)} f_low values x {N_REALIZATIONS} reals x 4 fits.")

# %% [markdown]
# ### Scenario 3: random loss (null test)
#
# Loss is independent of observable. Under known random selection, the correct likelihood has **no truncation term at all** — the survival probability is a constant that drops out of the MLE. So H1-Sel here reduces to the un-truncated Gaussian MLE, and H2-Sel reduces to H2-MLE. Consequently: H2-MLE and H2-Sel curves overlap exactly, and H1-Sel and H1-OLS agree up to the ddof-2 correction in $\sigma$. If they don't, something is wrong with the fitting machinery.

# %%
def scan_h1h2_random(f_low_grid, ratio, n_realizations, N_low, N_high,
                     M_edges_low, M_edges_high, gamma_truth=GAMMA_SCATTER,
                     seed_offset=8000, min_detected=10):
    """Same 4 fits, under random loss. Under random loss the correct
    likelihood has no truncation term, so H1-Sel and H2-Sel collapse to
    H1-untruncated and H2-untruncated. We still run all four for consistency.
    """
    n = len(f_low_grid)
    keys = ['f_low', 'f_high', 'f_total',
            'A_h1o', 'a_h1o', 's_h1o',
            'A_h1s', 'a_h1s', 's_h1s',
            'A_h2m', 'a_h2m', 's_h2m', 'g_h2m',
            'A_h2s', 'a_h2s', 's_h2s', 'g_h2s']
    results = {k: np.full((n, n_realizations), np.nan) for k in keys}

    init_h1 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE)
    init_h2 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE, gamma_truth)

    for i, fl in enumerate(f_low_grid):
        fh = ratio * fl
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng,
                                             gamma=gamma_truth)
            det = random_selection(y, bin_lab, fl, fh, rng)

            results['f_low'  ][i, j] = 1 - det[bin_lab == 0].mean()
            results['f_high' ][i, j] = 1 - det[bin_lab == 1].mean()
            results['f_total'][i, j] = 1 - det.mean()
            if det.sum() < min_detected:
                continue

            xd, yd = x[det], y[det]
            # Under known random selection: no truncation term needed.
            # H1-Sel becomes H1-untruncated; H2-Sel becomes H2-untruncated (same as H2-MLE).
            Ao,   ao,   so                = fit_ols(xd, yd)
            Ah1,  ah1,  sh1               = fit_selection_aware(xd, yd, -1e6, init=init_h1)
            Ah2m, ah2m, s0h2m, gh2m       = fit_h2_untrunc(xd, yd, init=init_h2)
            Ah2s, ah2s, s0h2s, gh2s       = fit_h2_untrunc(xd, yd, init=init_h2)

            results['A_h1o'][i,j], results['a_h1o'][i,j], results['s_h1o'][i,j] = Ao, ao, so
            results['A_h1s'][i,j], results['a_h1s'][i,j], results['s_h1s'][i,j] = Ah1, ah1, sh1
            results['A_h2m'][i,j], results['a_h2m'][i,j], results['s_h2m'][i,j], results['g_h2m'][i,j] = Ah2m, ah2m, s0h2m, gh2m
            results['A_h2s'][i,j], results['a_h2s'][i,j], results['s_h2s'][i,j], results['g_h2s'][i,j] = Ah2s, ah2s, s0h2s, gh2s
    return results


results_h1h2_rand = scan_h1h2_random(
    F_LOW_GRID, RATIO_HIGH_OVER_LOW, N_REALIZATIONS,
    N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
    gamma_truth=GAMMA_SCATTER, seed_offset=8000,
)
print(f"Random H1/H2 scan complete: {len(F_LOW_GRID)} f_low values x {N_REALIZATIONS} reals x 4 fits.")

# %% [markdown]
# ### Diagnostic: fitted MOR under each model
#
# One realisation at threshold $y_\mathrm{min} = -2.1$ ($f_\mathrm{total} \approx 30\%$). Both panels show the same data and same truth. The two panels differ only in *which family of fits* is drawn on top:
#
# - **Left panel (H1)**: constant-$\sigma$ fits. Their $\pm 1\sigma$ envelopes are **parallel** — same width at every mass by construction.
# - **Right panel (H2)**: mass-dependent-$\sigma$ fits. Their envelopes are **wedge-shaped**, matching the truth envelope's structure.
#
# The truth envelope (goldenrod, both panels) is wedge-shaped because $\gamma = -0.3$ makes $\sigma$ larger at low mass. The visual mismatch between H1's parallel envelopes and the truth's wedge is the *pictorial signature* of scatter-model mis-specification. H2-Sel recovers not just the mean line but the whole envelope shape.

# %%
FITS_STYLE = [
    ('H1-OLS',  'a_h1o', 's_h1o', 'A_h1o', None,     'navy',       'o', '-',  0.9),
    ('H1-Sel',  'a_h1s', 's_h1s', 'A_h1s', None,     'green',      's', '-',  0.9),
    ('H2-MLE',  'a_h2m', 's_h2m', 'A_h2m', 'g_h2m',  'crimson',    '^', '--', 0.9),
    ('H2-Sel',  'a_h2s', 's_h2s', 'A_h2s', 'g_h2s',  'darkorange', 'D', '--', 0.9),
]

def summary(a):
    return (np.nanmean(a, axis=1),
            np.nanpercentile(a, 16, axis=1),
            np.nanpercentile(a, 84, axis=1))


def plot_mean_relation_scan(results, title_suffix=''):
    """Two-panel scan plot: alpha and A vs f_total, four fits each."""
    f_tot_m, _, _ = summary(results['f_total'])
    fig, (ax_a, ax_A) = plt.subplots(1, 2, figsize=(13, 4.8))

    for label, akey, _, Akey, _, color, mk, ls, alpha in FITS_STYLE:
        a_m, a_lo, a_hi = summary(results[akey])
        A_m, A_lo, A_hi = summary(results[Akey])
        ax_a.plot(f_tot_m, a_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
        ax_a.fill_between(f_tot_m, a_lo, a_hi, color=color, alpha=0.12)
        ax_A.plot(f_tot_m, A_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
        ax_A.fill_between(f_tot_m, A_lo, A_hi, color=color, alpha=0.12)

    ax_a.axhline(ALPHA_TRUE, color='goldenrod', ls=':', lw=2, label=fr'Truth $\alpha$={ALPHA_TRUE}')
    ax_a.set_xlabel(r'$f_\mathrm{total}$'); ax_a.set_ylabel(r'Fitted slope $\alpha$')
    ax_a.set_title(f'Slope{title_suffix}'); ax_a.legend(fontsize=9)

    ax_A.axhline(A_TRUE, color='goldenrod', ls=':', lw=2, label=fr'Truth $A$={A_TRUE}')
    ax_A.set_xlabel(r'$f_\mathrm{total}$'); ax_A.set_ylabel(r'Fitted intercept $A$')
    ax_A.set_title(f'Intercept{title_suffix}'); ax_A.legend(fontsize=9)
    plt.tight_layout(); plt.show()


def plot_scatter_scan(results, title_suffix=''):
    """Three-panel scan plot: H1 sigma, H2 sigma_0, H2 gamma."""
    f_tot_m, _, _ = summary(results['f_total'])
    M_low_mid  = np.sqrt(M_EDGES_LOW[0]  * M_EDGES_LOW[1])
    M_high_mid = np.sqrt(M_EDGES_HIGH[0] * M_EDGES_HIGH[1])
    sig_tr_low  = sigma_of_M(M_low_mid,  sigma0=SIGMA_TRUE, gamma=GAMMA_SCATTER)
    sig_tr_high = sigma_of_M(M_high_mid, sigma0=SIGMA_TRUE, gamma=GAMMA_SCATTER)

    fig, (ax_s1, ax_s0, ax_g) = plt.subplots(1, 3, figsize=(16, 4.8))

    for label, _, skey, _, _, color, mk, ls, alpha in FITS_STYLE[:2]:
        s_m, s_lo, s_hi = summary(results[skey])
        ax_s1.plot(f_tot_m, s_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
        ax_s1.fill_between(f_tot_m, s_lo, s_hi, color=color, alpha=0.15)
    ax_s1.axhline(sig_tr_low,  color='goldenrod', ls=':',  lw=1.7,
                  label=fr'$\sigma_\mathrm{{true}}$(low)={sig_tr_low:.2f}')
    ax_s1.axhline(sig_tr_high, color='goldenrod', ls='-.', lw=1.7,
                  label=fr'$\sigma_\mathrm{{true}}$(high)={sig_tr_high:.2f}')
    ax_s1.set_xlabel(r'$f_\mathrm{total}$'); ax_s1.set_ylabel(r'Fitted $\sigma$ (const-$\sigma$)')
    ax_s1.set_title(f'H1: $\\sigma$ (mis-specified){title_suffix}'); ax_s1.legend(fontsize=8)

    for label, _, skey, _, _, color, mk, ls, alpha in FITS_STYLE[2:]:
        s_m, s_lo, s_hi = summary(results[skey])
        ax_s0.plot(f_tot_m, s_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
        ax_s0.fill_between(f_tot_m, s_lo, s_hi, color=color, alpha=0.15)
    ax_s0.axhline(SIGMA_TRUE, color='goldenrod', ls=':', lw=2,
                  label=fr'Truth $\sigma_0$={SIGMA_TRUE}')
    ax_s0.set_xlabel(r'$f_\mathrm{total}$'); ax_s0.set_ylabel(r'Fitted $\sigma_0$')
    ax_s0.set_title(f'H2: $\\sigma_0${title_suffix}'); ax_s0.legend(fontsize=8)

    for label, _, _, _, gkey, color, mk, ls, alpha in FITS_STYLE[2:]:
        g_m, g_lo, g_hi = summary(results[gkey])
        ax_g.plot(f_tot_m, g_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
        ax_g.fill_between(f_tot_m, g_lo, g_hi, color=color, alpha=0.15)
    ax_g.axhline(GAMMA_SCATTER, color='goldenrod', ls=':', lw=2,
                 label=fr'Truth $\gamma$={GAMMA_SCATTER}')
    ax_g.axhline(0.0, color='gray', ls='-', lw=0.7, alpha=0.4)
    ax_g.set_xlabel(r'$f_\mathrm{total}$'); ax_g.set_ylabel(r'Fitted $\gamma$')
    ax_g.set_title(f'H2: $\\gamma${title_suffix}'); ax_g.legend(fontsize=8)
    plt.tight_layout(); plt.show()


def plot_diagnostic_mor(M, x, y, bin_lab, detected, fits, selection_label,
                        threshold_marker=None, thresholds_per_bin=None):
    """Two-panel diagnostic: fitted MOR lines and envelopes on top of the mock.

    fits: dict with keys 'h1_ols', 'h1_sel', 'h2_mle', 'h2_sel', each a tuple of parameters:
          - H1 fits: (A, alpha, sigma)
          - H2 fits: (A, alpha, sigma0, gamma)
    selection_label: title suffix, e.g. 'threshold', 'fraction', 'random'.
    threshold_marker: single y_min value to plot as a vertical line (for threshold-based).
    thresholds_per_bin: (y_min_low, y_min_high) for fraction-based, or None.
    """
    logM_grid = np.linspace(np.log10(M_EDGES_LOW[0]) - 0.05,
                            np.log10(M_EDGES_HIGH[1]) + 0.05, 200)
    x_grid = np.log(10**logM_grid / M_PIV)

    def _line(A, a, xg): return A + a * xg
    def _env_const(A, a, s, xg):
        m = _line(A, a, xg); return m - s, m + s
    def _env_massdep(A, a, s0, g, xg):
        m = _line(A, a, xg); s_i = s0 * np.exp(g * xg); return m - s_i, m + s_i

    fig, (axL, axR) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
    for ax in (axL, axR):
        ax.scatter(y[detected],  np.log10(M[detected]),  c='black', s=22, label='Detected')
        ax.scatter(y[~detected], np.log10(M[~detected]), c='red',   s=22, marker='x', label='Lost')
        if threshold_marker is not None:
            ax.axvline(threshold_marker, color='gray', ls=':', lw=1,
                       label=fr'$y_{{\min}}$={threshold_marker}')
        if thresholds_per_bin is not None:
            ym_lo, ym_hi = thresholds_per_bin
            ax.axvline(ym_lo, color='gray', ls=':', lw=1, alpha=0.7,
                       label=fr'$y_{{\min}}^\mathrm{{low}}$={ym_lo:.2f}')
            ax.axvline(ym_hi, color='gray', ls='-.', lw=1, alpha=0.7,
                       label=fr'$y_{{\min}}^\mathrm{{high}}$={ym_hi:.2f}')
        # Truth
        mean_tr = _line(A_TRUE, ALPHA_TRUE, x_grid)
        lo_tr, hi_tr = _env_massdep(A_TRUE, ALPHA_TRUE, SIGMA_TRUE, GAMMA_SCATTER, x_grid)
        ax.plot(mean_tr, logM_grid, color='goldenrod', lw=2.5,
                label=fr'Truth ($\alpha$={ALPHA_TRUE}, $\gamma$={GAMMA_SCATTER})')
        ax.fill_betweenx(logM_grid, lo_tr, hi_tr, color='goldenrod', alpha=0.18,
                         label=r'Truth $\pm1\sigma$')
        ax.set_xlabel(r'$\ln\,\mathrm{Obs}$')

    # H1 panel
    for key, color, ls, name in [('h1_ols', 'navy', '-', 'H1-OLS'),
                                  ('h1_sel', 'green', '--', 'H1-Sel')]:
        A, a, s = fits[key]
        lo, hi = _env_const(A, a, s, x_grid)
        axL.plot(_line(A, a, x_grid), logM_grid, color=color, ls=ls, lw=2,
                 label=fr'{name} ($\alpha$={a:.2f}, $\sigma$={s:.2f})')
        axL.fill_betweenx(logM_grid, lo, hi, color=color, alpha=0.10)

    # H2 panel
    for key, color, ls, name in [('h2_mle',  'crimson',    '-',  'H2-MLE'),
                                  ('h2_sel',  'darkorange', '--', 'H2-Sel')]:
        A, a, s0, g = fits[key]
        lo, hi = _env_massdep(A, a, s0, g, x_grid)
        axR.plot(_line(A, a, x_grid), logM_grid, color=color, ls=ls, lw=2,
                 label=fr'{name} ($\alpha$={a:.2f}, $\sigma_0$={s0:.2f}, $\gamma$={g:+.2f})')
        axR.fill_betweenx(logM_grid, lo, hi, color=color, alpha=0.10)

    axL.set_title(r'H1: constant-$\sigma$ fits')
    axR.set_title(r'H2: mass-dependent-$\sigma$ fits')
    axL.set_ylabel(r'$\log_{10}(M / [M_\odot / h])$')
    for ax in (axL, axR):
        ax.legend(loc='upper left', fontsize=8)

    f_low_d  = 1 - detected[bin_lab==0].mean()
    f_high_d = 1 - detected[bin_lab==1].mean()
    f_tot_d  = 1 - detected.mean()
    plt.suptitle(fr'{selection_label}: $f_\mathrm{{low}}$={f_low_d:.0%}, '
                 fr'$f_\mathrm{{high}}$={f_high_d:.0%}, $f_\mathrm{{total}}$={f_tot_d:.0%}',
                 fontsize=11)
    plt.tight_layout(); plt.show()

# %%
# ---------- Threshold-based ----------
rng_diag = np.random.default_rng(11)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_diag,
                                  gamma=GAMMA_SCATTER)
Y_MIN_DIAG = -2.1
det = y > Y_MIN_DIAG
init_h1, init_h2 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE), (A_TRUE, ALPHA_TRUE, SIGMA_TRUE, GAMMA_SCATTER)
fits = {
    'h1_ols': fit_ols(x[det], y[det]),
    'h1_sel': fit_selection_aware(x[det], y[det], Y_MIN_DIAG, init=init_h1),
    'h2_mle': fit_h2_untrunc(x[det], y[det], init=init_h2),
    'h2_sel': fit_h2_sel(x[det], y[det], Y_MIN_DIAG, init=init_h2),
}
plot_diagnostic_mor(M, x, y, bin_lab, det, fits, 'Threshold selection',
                    threshold_marker=Y_MIN_DIAG)
plot_mean_relation_scan(results_h1h2,      title_suffix=' (threshold-based)')
plot_scatter_scan(     results_h1h2,      title_suffix=' (threshold-based)')

# ---------- Fraction-based ----------
rng_diag = np.random.default_rng(12)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_diag,
                                  gamma=GAMMA_SCATTER)
F_LOW_DIAG, F_HIGH_DIAG = 0.30, 0.15
det, (ym_lo, ym_hi) = fraction_based_selection(y, bin_lab, F_LOW_DIAG, F_HIGH_DIAG)
y_min_arr = np.where(bin_lab[det] == 0, ym_lo, ym_hi)
fits = {
    'h1_ols': fit_ols(x[det], y[det]),
    'h1_sel': fit_selection_aware_perpoint(x[det], y[det], y_min_arr, init=init_h1),
    'h2_mle': fit_h2_untrunc(x[det], y[det], init=init_h2),
    'h2_sel': fit_h2_sel_perpoint(x[det], y[det], y_min_arr, init=init_h2),
}
plot_diagnostic_mor(M, x, y, bin_lab, det, fits, 'Fraction-based selection',
                    thresholds_per_bin=(ym_lo, ym_hi))
plot_mean_relation_scan(results_h1h2_frac, title_suffix=' (fraction-based)')
plot_scatter_scan(     results_h1h2_frac, title_suffix=' (fraction-based)')

# ---------- Random loss ----------
rng_diag = np.random.default_rng(13)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_diag,
                                  gamma=GAMMA_SCATTER)
det = random_selection(y, bin_lab, F_LOW_DIAG, F_HIGH_DIAG, rng_diag)
fits = {
    'h1_ols': fit_ols(x[det], y[det]),
    'h1_sel': fit_selection_aware(x[det], y[det], -1e6, init=init_h1),
    'h2_mle': fit_h2_untrunc(x[det], y[det], init=init_h2),
    'h2_sel': fit_h2_untrunc(x[det], y[det], init=init_h2),   # collapses to MLE under random
}
plot_diagnostic_mor(M, x, y, bin_lab, det, fits, 'Random loss (null test)')
plot_mean_relation_scan(results_h1h2_rand, title_suffix=' (random loss)')
plot_scatter_scan(     results_h1h2_rand, title_suffix=' (random loss)')

# %%
rng_diag = np.random.default_rng(11)
M, x, y, bin_lab = generate_mock(N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH, rng_diag,
                                  gamma=GAMMA_SCATTER)
Y_MIN_DIAG = -2.1
detected = y > Y_MIN_DIAG

init_h1 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE)
init_h2 = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE, GAMMA_SCATTER)

Ao,  ao,  so                = fit_ols(x[detected], y[detected])
Ah1, ah1, sh1               = fit_selection_aware(x[detected], y[detected], Y_MIN_DIAG, init=init_h1)
Ah2m, ah2m, s0h2m, gh2m     = fit_h2_untrunc(x[detected], y[detected], init=init_h2)
Ah2s, ah2s, s0h2s, gh2s     = fit_h2_sel(x[detected], y[detected], Y_MIN_DIAG, init=init_h2)

# Grid over full mass range for smooth lines & envelopes
logM_grid = np.linspace(np.log10(M_EDGES_LOW[0]) - 0.05,
                        np.log10(M_EDGES_HIGH[1]) + 0.05, 200)
x_grid = np.log(10**logM_grid / M_PIV)

def _line(A, a, xg):  return A + a * xg
def _env_const(A, a, s, xg):
    m = _line(A, a, xg);  return m - s, m + s
def _env_massdep(A, a, s0, g, xg):
    m = _line(A, a, xg);  s_i = s0 * np.exp(g * xg);  return m - s_i, m + s_i

fig, (axL, axR) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)

for ax in (axL, axR):
    ax.scatter(y[detected],  np.log10(M[detected]),  c='black', s=22, label='Detected')
    ax.scatter(y[~detected], np.log10(M[~detected]), c='red',   s=22, marker='x', label='Lost')
    ax.axvline(Y_MIN_DIAG, color='gray', ls=':', lw=1,
               label=fr'$y_{{\min}}$={Y_MIN_DIAG}')

    # Truth (mass-dep envelope) on both panels
    mean_tr = _line(A_TRUE, ALPHA_TRUE, x_grid)
    lo_tr, hi_tr = _env_massdep(A_TRUE, ALPHA_TRUE, SIGMA_TRUE, GAMMA_SCATTER, x_grid)
    ax.plot(mean_tr, logM_grid, color='goldenrod', lw=2.5,
            label=fr'Truth ($\alpha$={ALPHA_TRUE}, $\gamma$={GAMMA_SCATTER})')
    ax.fill_betweenx(logM_grid, lo_tr, hi_tr, color='goldenrod', alpha=0.18,
                     label=r'Truth $\pm 1\sigma$ envelope')
    ax.set_xlabel(r'$\ln\,\mathrm{Obs}$')

# Left panel: H1 fits
for A, a, s, color, ls, label in [
    (Ao,  ao,  so,  'navy',  '-',  fr'H1-OLS ($\alpha$={ao:.2f}, $\sigma$={so:.2f})'),
    (Ah1, ah1, sh1, 'green', '--', fr'H1-Sel ($\alpha$={ah1:.2f}, $\sigma$={sh1:.2f})'),
]:
    lo, hi = _env_const(A, a, s, x_grid)
    axL.plot(_line(A, a, x_grid), logM_grid, color=color, ls=ls, lw=2, label=label)
    axL.fill_betweenx(logM_grid, lo, hi, color=color, alpha=0.10)

# Right panel: H2 fits
for A, a, s0, g, color, ls, label in [
    (Ah2m, ah2m, s0h2m, gh2m, 'crimson',    '-',
        fr'H2-MLE ($\alpha$={ah2m:.2f}, $\sigma_0$={s0h2m:.2f}, $\gamma$={gh2m:+.2f})'),
    (Ah2s, ah2s, s0h2s, gh2s, 'darkorange', '--',
        fr'H2-Sel ($\alpha$={ah2s:.2f}, $\sigma_0$={s0h2s:.2f}, $\gamma$={gh2s:+.2f})'),
]:
    lo, hi = _env_massdep(A, a, s0, g, x_grid)
    axR.plot(_line(A, a, x_grid), logM_grid, color=color, ls=ls, lw=2, label=label)
    axR.fill_betweenx(logM_grid, lo, hi, color=color, alpha=0.10)

axL.set_title('H1: constant-$\\sigma$ fits (envelopes parallel by construction)')
axR.set_title('H2: mass-dependent-$\\sigma$ fits (envelopes taper with mass)')
axL.set_ylabel(r'$\log_{10}(M / [M_\odot / h])$')
for ax in (axL, axR):
    ax.legend(loc='upper left', fontsize=8)

f_low_d  = 1 - detected[bin_lab==0].mean()
f_high_d = 1 - detected[bin_lab==1].mean()
f_tot_d  = 1 - detected.mean()
plt.suptitle(fr'Threshold selection: $f_\mathrm{{low}}$={f_low_d:.0%}, '
             fr'$f_\mathrm{{high}}$={f_high_d:.0%}, $f_\mathrm{{total}}$={f_tot_d:.0%}',
             fontsize=11)
plt.tight_layout()
plt.show()

# %%
def summary(a):
    return (np.nanmean(a, axis=1),
            np.nanpercentile(a, 16, axis=1),
            np.nanpercentile(a, 84, axis=1))

R = results_h1h2
f_tot_m, _, _ = summary(R['f_total'])

# Four-fit style dictionary — reused across panels
FITS = [
    ('H1-OLS',  'a_h1o', 's_h1o', 'A_h1o', None,     'navy',       'o', '-',  0.9),
    ('H1-Sel',  'a_h1s', 's_h1s', 'A_h1s', None,     'green',      's', '-',  0.9),
    ('H2-MLE',  'a_h2m', 's_h2m', 'A_h2m', 'g_h2m',  'crimson',    '^', '--', 0.9),
    ('H2-Sel',  'a_h2s', 's_h2s', 'A_h2s', 'g_h2s',  'darkorange', 'D', '--', 0.9),
]

fig, (ax_a, ax_A) = plt.subplots(1, 2, figsize=(13, 4.8))

for label, akey, _, Akey, _, color, mk, ls, alpha in FITS:
    a_m, a_lo, a_hi = summary(R[akey])
    A_m, A_lo, A_hi = summary(R[Akey])
    ax_a.plot(f_tot_m, a_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
    ax_a.fill_between(f_tot_m, a_lo, a_hi, color=color, alpha=0.12)
    ax_A.plot(f_tot_m, A_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
    ax_A.fill_between(f_tot_m, A_lo, A_hi, color=color, alpha=0.12)

ax_a.axhline(ALPHA_TRUE, color='goldenrod', ls=':', lw=2, label=fr'Truth $\alpha$={ALPHA_TRUE}')
ax_a.set_xlabel(r'$f_\mathrm{total}$')
ax_a.set_ylabel(r'Fitted slope $\alpha$')
ax_a.set_title(fr'Slope (truth: mass-dep scatter, $\gamma$={GAMMA_SCATTER})')
ax_a.legend(fontsize=9)

ax_A.axhline(A_TRUE, color='goldenrod', ls=':', lw=2, label=fr'Truth $A$={A_TRUE}')
ax_A.set_xlabel(r'$f_\mathrm{total}$')
ax_A.set_ylabel(r'Fitted intercept $A$')
ax_A.set_title('Intercept')
ax_A.legend(fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Compute per-bin truth values for the H1 sigma panel
M_low_mid  = np.sqrt(M_EDGES_LOW[0]  * M_EDGES_LOW[1])
M_high_mid = np.sqrt(M_EDGES_HIGH[0] * M_EDGES_HIGH[1])
sig_true_low  = sigma_of_M(M_low_mid,  sigma0=SIGMA_TRUE, gamma=GAMMA_SCATTER)
sig_true_high = sigma_of_M(M_high_mid, sigma0=SIGMA_TRUE, gamma=GAMMA_SCATTER)

fig, (ax_s1, ax_s0, ax_g) = plt.subplots(1, 3, figsize=(16, 4.8))

# --- Panel 1: sigma from H1 fits (constant-sigma model, single number per fit) ---
for label, _, skey, _, gkey, color, mk, ls, alpha in FITS[:2]:   # H1 fits only
    s_m, s_lo, s_hi = summary(R[skey])
    ax_s1.plot(f_tot_m, s_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
    ax_s1.fill_between(f_tot_m, s_lo, s_hi, color=color, alpha=0.15)

ax_s1.axhline(sig_true_low,  color='goldenrod', ls=':',  lw=1.7,
              label=fr'$\sigma_\mathrm{{true}}$(low bin) = {sig_true_low:.2f}')
ax_s1.axhline(sig_true_high, color='goldenrod', ls='-.', lw=1.7,
              label=fr'$\sigma_\mathrm{{true}}$(high bin) = {sig_true_high:.2f}')
ax_s1.set_xlabel(r'$f_\mathrm{total}$')
ax_s1.set_ylabel(r'Fitted $\sigma$ (constant-$\sigma$ model)')
ax_s1.set_title(r'H1: single $\sigma$ from mis-specified fit')
ax_s1.legend(fontsize=8)

# --- Panel 2: sigma_0 from H2 fits (mass-dep model, well-defined pivot value) ---
for label, _, skey, _, gkey, color, mk, ls, alpha in FITS[2:]:   # H2 fits only
    s_m, s_lo, s_hi = summary(R[skey])
    ax_s0.plot(f_tot_m, s_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
    ax_s0.fill_between(f_tot_m, s_lo, s_hi, color=color, alpha=0.15)

ax_s0.axhline(SIGMA_TRUE, color='goldenrod', ls=':', lw=2,
              label=fr'Truth $\sigma_0$={SIGMA_TRUE}')
ax_s0.set_xlabel(r'$f_\mathrm{total}$')
ax_s0.set_ylabel(r'Fitted $\sigma_0$ (at $M_\mathrm{piv}$)')
ax_s0.set_title(r'H2: $\sigma_0$ from correctly-specified fit')
ax_s0.legend(fontsize=8)

# --- Panel 3: gamma from H2 fits ---
for label, _, _, _, gkey, color, mk, ls, alpha in FITS[2:]:      # H2 fits only
    g_m, g_lo, g_hi = summary(R[gkey])
    ax_g.plot(f_tot_m, g_m, marker=mk, ls=ls, color=color, lw=2, alpha=alpha, label=label)
    ax_g.fill_between(f_tot_m, g_lo, g_hi, color=color, alpha=0.15)

ax_g.axhline(GAMMA_SCATTER, color='goldenrod', ls=':', lw=2,
             label=fr'Truth $\gamma$={GAMMA_SCATTER}')
ax_g.axhline(0.0, color='gray', ls='-', lw=0.7, alpha=0.4)   # zero reference
ax_g.set_xlabel(r'$f_\mathrm{total}$')
ax_g.set_ylabel(r'Fitted $\gamma$')
ax_g.set_title(r'H2: mass-dependence $\gamma$')
ax_g.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13 — How much knowledge of the selection is enough?
#
# Real surveys never fully characterise their completeness. The question this section answers is not *"what happens at different levels of smoothness?"* but rather:
#
# > **Fix the truth. Give the fit progressively better knowledge of it. At what point does MOR recovery stop being biased?**
#
# ### Setup
#
# - **Truth (fixed):** smooth completeness curve with width $\sigma_\mathrm{det}^\mathrm{true}$. This is a property of the physical survey.
# - **Fit (varying):** assumes smooth completeness with width $\sigma_\mathrm{det}^\mathrm{model}$. This is what the analyst has calibrated.
# - **Scan variable:** the *knowledge ratio* $k = \sigma_\mathrm{det}^\mathrm{model} / \sigma_\mathrm{det}^\mathrm{true}$.
#   - $k \to 0$: fit assumes a hard threshold. Zero knowledge of the smoothness.
#   - $k = 1$: fit knows the truth exactly. Full knowledge.
#   - $k > 1$: fit overestimates the smoothness.
#
# ### The likelihood
#
# For the fit to model smoothness properly, its selection-aware likelihood needs to account for both the smooth curve's effect on each detected point AND the normalization over all possible outcomes. The closed form is:
#
# $$\ln P(y_i \mid x_i, \text{det}) = \ln \phi(y_i; \mu_i, \sigma_i) + \ln \Phi\!\left(\frac{y_i - y_\mathrm{min}^\mathrm{soft}}{\sigma_\mathrm{det}^\mathrm{model}}\right) - \ln \Phi\!\left(\frac{\mu_i - y_\mathrm{min}^\mathrm{soft}}{\sqrt{\sigma_i^2 + (\sigma_\mathrm{det}^\mathrm{model})^2}}\right)$$
#
# The normalization term uses the standard Gaussian-times-Gaussian-CDF integral (see Kelly 2007 §5.2; Mantz+10 Paper I §4.1.2). At $\sigma_\mathrm{det}^\mathrm{model} \to 0$ it reduces to the truncated Gaussian likelihood you already have — the fit believes selection is a hard step.
#
# ### What the plot answers
#
# For any tolerance you're willing to accept (say ±3% bias in α), you can read off the minimum $k$ at which the fit stays within tolerance. That is the calibration requirement for a real survey.cale surveys.

# %%
def smooth_curve_selection(y, y_min_soft, sigma_det, rng):
    """Truth-side selection: pure smooth completeness curve, no hard cut.
    P(surv | y) = Phi((y - y_min_soft) / sigma_det).
    """
    surv_prob = norm.cdf((y - y_min_soft) / sigma_det)
    return rng.uniform(0, 1, size=len(y)) < surv_prob


def neg_loglike_h2_smooth(params, x, y, y_min_soft, sigma_det_model):
    """Selection-aware H2 log-likelihood with a smooth completeness model.

    Three terms per point:
      (i)   Gaussian density of y given the MOR
      (ii)  Log survival probability of this specific point under the smooth curve
      (iii) Log total detection probability at this mass (normalization),
            given by the analytic Gaussian * Gaussian-CDF integral:
            Phi((mu - y_min_soft) / sqrt(sigma_i^2 + sigma_det_model^2))

    At sigma_det_model -> 0 this reduces to the truncated Gaussian likelihood
    (fit assumes a hard threshold). A small floor prevents numerical blow-up.
    """
    A, alpha, log_sigma0, gamma = params
    sigma0 = np.exp(log_sigma0)
    sigma_i = sigma0 * np.exp(gamma * x)
    mu = A + alpha * x
    sdm = max(sigma_det_model, 1e-4)

    log_pdf         = norm.logpdf(y, mu, sigma_i)
    log_surv_point  = norm.logcdf((y - y_min_soft) / sdm)
    combined_sigma  = np.sqrt(sigma_i ** 2 + sdm ** 2)
    log_total_surv  = norm.logcdf((mu - y_min_soft) / combined_sigma)

    return -np.sum(log_pdf + log_surv_point - log_total_surv)


def fit_h2_smooth(x, y, y_min_soft, sigma_det_model, init=(0.0, 1.5, 0.2, 0.0)):
    """Fit H2 assuming smooth completeness at sigma_det_model.
    sigma_det_model is a KNOWN input, not a fitted parameter — it represents
    how much of the true completeness curve the fit is aware of.
    """
    if len(x) < 4:
        return np.nan, np.nan, np.nan, np.nan
    x0 = [init[0], init[1], np.log(init[2]), init[3]]
    r = minimize(neg_loglike_h2_smooth, x0=x0,
                 args=(x, y, y_min_soft, sigma_det_model),
                 method='Nelder-Mead',
                 options={'xatol': 1e-5, 'fatol': 1e-5, 'maxiter': 20000})
    if not r.success:
        return np.nan, np.nan, np.nan, np.nan
    A, alpha, log_sigma0, gamma = r.x
    return A, alpha, np.exp(log_sigma0), gamma

# %%
def scan_knowledge_ratio(sd_true, k_grid, n_realizations,
                          N_low, N_high, M_edges_low, M_edges_high,
                          y_min_soft, gamma_truth=GAMMA_SCATTER,
                          seed_offset=30000, min_detected=10):
    """For a FIXED true smoothness sd_true, scan the fit's knowledge ratio k.

    At each k, the fit assumes smooth completeness at sigma_det_model = k * sd_true.
    Truth is always smooth completeness at sd_true.
    """
    n = len(k_grid)
    keys = ['A', 'alpha', 'sigma0', 'gamma', 'f_total']
    results = {kk: np.full((n, n_realizations), np.nan) for kk in keys}
    init = (A_TRUE, ALPHA_TRUE, SIGMA_TRUE, gamma_truth)

    for i, k in enumerate(k_grid):
        sd_model = k * sd_true
        for j in range(n_realizations):
            rng = np.random.default_rng(seed_offset + i * 1000 + j)
            M, x, y, bin_lab = generate_mock(N_low, N_high,
                                             M_edges_low, M_edges_high, rng,
                                             gamma=gamma_truth)
            det = smooth_curve_selection(y, y_min_soft, sd_true, rng)
            results['f_total'][i, j] = 1 - det.mean()
            if det.sum() < min_detected:
                continue
            A, a, s0, g = fit_h2_smooth(x[det], y[det], y_min_soft, sd_model, init=init)
            # Filter obvious convergence failures — occasional at small k with large sd_true
            if np.isnan(a) or abs(a - ALPHA_TRUE) > 1.0 or abs(A) > 2.0:
                continue
            results['A'    ][i, j] = A
            results['alpha'][i, j] = a
            results['sigma0'][i, j] = s0
            results['gamma'][i, j] = g

    return results


# Log-ish spacing on k gives resolution where the threshold happens
K_GRID = np.array([0.05, 0.1, 0.15, 0.25, 0.4, 0.6, 0.8, 1.0, 1.25, 1.5])
Y_MIN_SOFT = -2.1

# Scan multiple sd_true values to see how the threshold depends on the survey's smoothness.
SD_TRUE_LIST = [0.2, 0.4]
results_knowledge = {
    sd_true: scan_knowledge_ratio(sd_true, K_GRID, N_REALIZATIONS,
                                   N_LOW, N_HIGH, M_EDGES_LOW, M_EDGES_HIGH,
                                   y_min_soft=Y_MIN_SOFT)
    for sd_true in SD_TRUE_LIST
}
print(f"Knowledge scan complete for sd_true in {SD_TRUE_LIST}.")
# Out:
# Knowledge scan complete for sd_true in [0.2, 0.4].

# %%
def plot_knowledge_scan(results_dict, k_grid, tolerances=None):
    """results_dict: {sd_true: scan_results}. Plot bias vs k for alpha, sigma0, gamma."""
    if tolerances is None:
        tolerances = {'alpha': 0.03, 'sigma0': 0.02, 'gamma': 0.05}
    colors = ['navy', 'crimson', 'darkgreen']
    markers = ['o', 's', 'D']

    fig, axes = plt.subplots(1, 3, figsize=(15, 4.8))

    for ax, key, truth, ylabel, title in [
        (axes[0], 'alpha',  ALPHA_TRUE,     r'Fitted $\alpha$',     r'Slope $\alpha$'),
        (axes[1], 'sigma0', SIGMA_TRUE,     r'Fitted $\sigma_0$',   r'Scatter amplitude $\sigma_0$'),
        (axes[2], 'gamma',  GAMMA_SCATTER,  r'Fitted $\gamma$',     r'Scatter mass-dep $\gamma$'),
    ]:
        tol = tolerances[key]
        # Tolerance band around truth (drawn first so curves overlay)
        ax.axhspan(truth - tol, truth + tol, color='goldenrod', alpha=0.10,
                   label=fr'$\pm${tol} tolerance')
        ax.axhline(truth, color='goldenrod', ls=':', lw=2, label=f'Truth ({truth})')
        ax.axvline(1.0, color='gray', ls='--', lw=1, alpha=0.6, label='k=1 (full knowledge)')

        for (sd_true, r), color, mk in zip(results_dict.items(), colors, markers):
            d_med = np.nanmedian(r[key], axis=1)
            d_lo  = np.nanpercentile(r[key], 16, axis=1)
            d_hi  = np.nanpercentile(r[key], 84, axis=1)
            ax.plot(k_grid, d_med, marker=mk, ls='-', color=color, lw=2,
                    label=fr'$\sigma_\mathrm{{det}}^\mathrm{{true}}$={sd_true}')
            ax.fill_between(k_grid, d_lo, d_hi, color=color, alpha=0.15)

        ax.set_xlabel(r'$k = \sigma_\mathrm{det}^\mathrm{model} / \sigma_\mathrm{det}^\mathrm{true}$')
        ax.set_ylabel(ylabel)
        ax.set_title(title)
        ax.legend(fontsize=8, loc='best')

    plt.tight_layout()
    plt.show()


plot_knowledge_scan(results_knowledge, K_GRID,
                     tolerances={'alpha': 0.03, 'sigma0': 0.02, 'gamma': 0.05})

# %%
def find_knowledge_threshold(results, k_grid, key, truth, tolerance):
    """Find the minimum k at which |median(fit) - truth| stays within tolerance
    for ALL k values above that point.
    Returns np.nan if never within tolerance, or 0 if within tolerance everywhere.
    """
    d_med = np.nanmedian(results[key], axis=1)
    within = np.abs(d_med - truth) <= tolerance
    if within.all():
        return 0.0
    if not within.any():
        return np.nan
    # Find the largest k that's OUTSIDE tolerance, threshold is just above it
    outside_idx = np.where(~within)[0]
    last_outside = outside_idx.max()
    if last_outside == len(k_grid) - 1:
        return np.nan  # Never enters tolerance
    return k_grid[last_outside + 1]


print("\nMinimum knowledge k required to keep bias within tolerance:")
print(f"{'sd_true':>8} {'k*_alpha':>10} {'k*_sigma0':>10} {'k*_gamma':>10}")
for sd_true, r in results_knowledge.items():
    k_a  = find_knowledge_threshold(r, K_GRID, 'alpha',  ALPHA_TRUE,    0.03)
    k_s0 = find_knowledge_threshold(r, K_GRID, 'sigma0', SIGMA_TRUE,    0.02)
    k_g  = find_knowledge_threshold(r, K_GRID, 'gamma',  GAMMA_SCATTER, 0.05)
    print(f"{sd_true:8.2f} {k_a:10.2f} {k_s0:10.2f} {k_g:10.2f}")
# Out:
# Minimum knowledge k required to keep bias within tolerance:
#  sd_true   k*_alpha  k*_sigma0   k*_gamma
#     0.20       0.10       0.00       0.00
#     0.40       0.60       0.00       0.00

# %% [markdown]
# ## 11 — Takeaways and connection to `hmf_mor_forecast.py`
#
# **Two selection geometries, two bias patterns, one solution.** Under threshold-based selection with a wide bin gap, the low bin is heavily truncated and the high bin is untouched — the slope $\alpha$ and intercept $A$ take the biggest hit while $\sigma$ is only mildly biased (the high bin anchors it). Under fraction-based selection with truncation in *both* bins, both centroids pivot upward together — the slope bias shrinks (less differential pivot) but the $\sigma$ bias grows and becomes monotonic. In both regimes, the selection-aware MLE recovers all three parameters within the realisation band by conditioning the likelihood on the (possibly bin-dependent) truncation threshold.
#
# **Which parameter is most vulnerable depends on the geometry.** With a wide mass lever arm and asymmetric selection, worry about the *mean* relation. With balanced selection across the mass range, worry about the *scatter*. There is no universal "most-biased parameter" of a scaling relation under selection — it depends on where the cuts bite.
#
# **Why $\sigma$ can look stable even under strong selection.** In the two-bin threshold case, the untouched high bin anchors the intrinsic width; in the endpoint region of the threshold scan, OLS $\sigma$ even *recovers* because only the untouched high bin is being fit. This isn't OLS "healing" — it's OLS fitting a subset of data that happens to be untruncated. A caution against reading $\sigma$ recovery as evidence that selection is being handled correctly.
#
# **Connection to `hmf_mor_forecast.py`.** The selection-aware likelihood in this notebook is the per-point continuous analogue of the migration matrix in your pipeline. Both are forward-modelling operations: convolve the underlying MOR through a response function to get a prediction that lives in the same space as the observed data. In `hmf_mor_forecast.py`, the response is $P_{ij} = P(\text{observed bin } i \mid \text{true bin } j)$, applied to true counts under a Poisson likelihood on binned cluster counts. In this notebook, the response is the Gaussian survival function $P(y > y_\mathrm{min} \mid x)$, applied per detected cluster under a Gaussian likelihood on individual observables. Different observables (counts vs individual objects), different noise models (Poisson vs Gaussian), same principle: **do not fit observed data with a model that pretends the response function is trivial**.
#
# Two features of `hmf_mor_forecast.py` extend beyond what this notebook covers:
#
# - **Mass-dependent (observable-dependent) scatter** via `gamma_scatter`: $\sigma_{\ln O}(M) = \mathtt{frac\_scatter} \cdot (M/M_\mathrm{piv})^{\gamma}$, following the standard power-law trend used for X-ray L–M and Y–M relations ([Evrard et al. 2014](https://arxiv.org/abs/1403.1456); [Mantz et al. 2016](https://arxiv.org/abs/1606.03407)). This is the natural cousin of our fraction-based selection — the response function varies with mass. Setting `gamma_scatter = 0` recovers the constant-scatter behaviour that this notebook uses throughout.
# - **Separate `P_data` (truth, frozen at setup) vs `P_model` (rebuilt each MCMC step from the sampled scatter parameters)**: lets you deliberately misspecify the scatter model and measure the resulting bias in recovered cosmology. This is the *wrong-fixed* / *free* / *marginalise* structure at the heart of your project; this notebook builds the low-level intuition for why that misspecification matters in the first place.
#
# References for the theory: [Kelly 2007](https://arxiv.org/abs/0705.2774) §5 for the per-point selection-aware likelihood; [Mantz 2019](https://arxiv.org/abs/1902.06791) for a modern generalised treatment; the migration-matrix approach applied to cluster counts is used throughout the eROSITA cosmology chain ([Ghirardini et al. 2024](https://arxiv.org/abs/2402.08458)).
#
# **Caveat on the fraction-based selection-aware fit.** We used the empirical $y_\mathrm{min}$ per bin (the observable value of the lowest surviving cluster) as the per-point truncation threshold. This is slightly circular — the threshold is measured from the same data being fit. In a real analysis, completeness would come from external injection–recovery tests. As $N$ per bin grows, the empirical threshold converges to the true bin-dependent completeness edge, so the bias from this circularity vanishes in the survey-scale limit.
#
# ## Suggested next steps
# - **Switch to threshold on $L_X$ or $Y_{SZ}$** with realistic units — would let you compare $y_\mathrm{min}$ against literature completeness curves (e.g. from Ghirardini+24 for eRASS1).
# - **Test mass-dependent scatter directly**: pipe `gamma_scatter` ≠ 0 through this notebook's data generator, then fit with a constant-scatter model. This is the per-point analogue of running `hmf_mor_forecast.py` with `gamma_scatter_data ≠ 0` and `gamma_scatter_model = 0` (the "shape-misspecified" case) — it should visibly bias the recovered $\sigma$ and $\alpha$ even under the *correct* selection.
# - **Add per-point measurement error** ($y_i \to y_i + \eta_i$, $\eta \sim \mathcal{N}(0, \sigma_\mathrm{meas})$) and repeat: separates "lost the intrinsic tail" from "noisy scatter above the cut". Kelly 2007 gives the extended likelihood form.
# - **Draw masses from a Tinker08 HMF** instead of uniform-in-$\log M$ — mildly amplifies the low-mass biases and matches the mass prior implicit in `hmf_mor_forecast.py`.
# - **Vary the two-bin geometry** (narrower gap, more bins) to map out the regime where $\sigma$ becomes the sensitive parameter vs where $\alpha$ dominates.
# - **Add a Bayesian version** with `emcee` on the truncated likelihood — corner plot of $(A, \alpha, \sigma)$ posterior under OLS-style vs correct likelihood. Directly parallels your CosmoSIS chains and would let you show marginalised covariances.sed covariances.
